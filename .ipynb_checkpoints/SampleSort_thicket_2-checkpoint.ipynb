# %% [markdown]
# # FINAL PROJECT THICKET

# %%
import sys
sys.path.append("/scratch/group/csce435-f23/python-3.8.17/lib/python3.8/site-packages")
sys.path.append("/scratch/group/csce435-f23/thicket")
from glob import glob

import matplotlib.pyplot as plt
plt.rcParams.update({'figure.max_open_warning': 0})
import pandas as pd

import thicket as th

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

print("done")
# Out:
# done

# %% [markdown]
# Read in all the files

# %% [markdown]
# # MPI Thicket Variables

# %%
mpi_random_tk = th.Thicket.from_caliperreader(glob("cali_files/sort3/*-sample.cali"))
mpi_perturbed_tk = th.Thicket.from_caliperreader(glob("cali_files/sort2/*-sample.cali"))
mpi_sorted_tk = th.Thicket.from_caliperreader(glob("cali_files/sort0/*sample.cali"))
mpi_reverse_tk = th.Thicket.from_caliperreader(glob("cali_files/sort1/*sample.cali"))

# %% [markdown]
# # CUDA Thicket Variables

# %%
# cuda_random_tk = th.Thicket.from_caliperreader(glob("cali_files/Bitonic_cali_files/*.cali"))
# cuda_perturbed_tk = th.Thicket.from_caliperreader(glob("cali_files/Bitonic_cali_files/*.cali"))
# cuda_sorted_tk = th.Thicket.from_caliperreader(glob("cali_files/Bitonic_cali_files/*.cali"))
# cuda_reverse_tk = th.Thicket.from_caliperreader(glob("cali_files/Bitonic_cali_files/*.cali"))

# %%
tks = {}

tks["mpi_sorted"] = mpi_sorted_tk
tks["mpi_reverse"] = mpi_reverse_tk
tks["mpi_random"] = mpi_random_tk
tks["mpi_perturbed"] = mpi_perturbed_tk

# tks["cuda_sorted"] = cuda_sorted_tk
# tks["cuda_reverse"] = cuda_reverse_tk
# tks["cuda_random"] = cuda_random_tk
# tks["cuda_perturbed"] = cuda_perturbed_tk

# %%
for i in tks.values():
    i.statsframe.dataframe["time"] = 1

# print(tks["cuda_random"].tree())

# %%
# Performance data
for inputType in tks.keys():
    if "mpi" in inputType:
        tks[inputType].metadata["values_per_proc"] = tks[inputType].metadata["InputSize"] // tks[inputType].metadata["num_procs"]
        
tks["mpi_random"].metadata
# Out:
#            cali.caliper.version  mpi.world.size  \
# profile
# 96387453             2.11.0-dev               8
# 125094042            2.11.0-dev              64
# 136462064            2.11.0-dev            1024
# 224262369            2.11.0-dev               8
# 226423909            2.11.0-dev               8
# 236817265            2.11.0-dev             256
# 254330487            2.11.0-dev               8
# 267055606            2.11.0-dev              64
# 328894138            2.11.0-dev            1024
# 366907904            2.11.0-dev              32
# 369740256            2.11.0-dev             512
# 478579561            2.11.0-dev             256
# 485392475            2.11.0-dev             512
# 491488988            2.11.0-dev               2
# 498735902            2.11.0-dev             128
# 512550339            2.11.0-dev              32
# 515405417            2.11.0-dev             128
# 534472231            2.11.0-dev              32
# 561425512            2.11.0-dev              32
# 577358404            2.11.0-dev             256
# 591006971            2.11.0-dev             512
# 602430384            2.11.0-dev              32
# 689404126            2.11.0-dev              16
# 791874404            2.11.0-dev             512
# 866384639            2.11.0-dev               8
# 914308246            2.11.0-dev             512
# 939046943            2.11.0-dev             128
# 1058089730           2.11.0-dev               8
# 1063817247           2.11.0-dev              64
# 1112895243           2.11.0-dev             256
# 1125817381           2.11.0-dev               2
# 1127408257           2.11.0-dev               4
# 1132568813           2.11.0-dev             512
# 1178857823           2.11.0-dev              32
# 1208028574           2.11.0-dev             256
# 1219508416           2.11.0-dev               2
# 1229844398           2.11.0-dev             128
# 1233138883           2.11.0-dev              32
# 1235336969           2.11.0-dev             512
# 1244749383           2.11.0-dev               8
# 1252107835           2.11.0-dev              16
# 1255156828           2.11.0-dev              64
# 1277230400           2.11.0-dev             256
# 1285908972           2.11.0-dev             512
# 1334413436           2.11.0-dev              32
# 1342788810           2.11.0-dev               4
# 1354911456           2.11.0-dev             256
# 1360757312           2.11.0-dev            1024
# 1415354612           2.11.0-dev             512
# 1452988688           2.11.0-dev               4
# 1467409442           2.11.0-dev             128
# 1510749833           2.11.0-dev               4
# 1514005273           2.11.0-dev              64
# 1552742471           2.11.0-dev               8
# 1571739899           2.11.0-dev             512
# 1594575338           2.11.0-dev             256
# 1618502310           2.11.0-dev               2
# 1646947451           2.11.0-dev              64
# 1688383690           2.11.0-dev               4
# 1701506829           2.11.0-dev            1024
# 1790927496           2.11.0-dev              64
# 1798249285           2.11.0-dev             256
# 1844985577           2.11.0-dev              32
# 1850520422           2.11.0-dev             256
# 1898457644           2.11.0-dev              32
# 1925583792           2.11.0-dev               8
# 1930022590           2.11.0-dev             256
# 1941721610           2.11.0-dev              32
# 1946102318           2.11.0-dev               4
# 1946591664           2.11.0-dev               2
# 1947014976           2.11.0-dev              16
# 1963726364           2.11.0-dev               4
# 1963771600           2.11.0-dev              16
# 1993344714           2.11.0-dev            1024
# 2071331326           2.11.0-dev             128
# 2200548846           2.11.0-dev            1024
# 2202992537           2.11.0-dev             128
# 2209562025           2.11.0-dev             256
# 2239031269           2.11.0-dev            1024
# 2243547470           2.11.0-dev               8
# 2251050041           2.11.0-dev             256
# 2275966125           2.11.0-dev               4
# 2299812503           2.11.0-dev               8
# 2307843172           2.11.0-dev             256
# 2309438091           2.11.0-dev             512
# 2338225906           2.11.0-dev              16
# 2353328152           2.11.0-dev             128
# 2379841991           2.11.0-dev              16
# 2385682507           2.11.0-dev               8
# 2418087398           2.11.0-dev               2
# 2430489637           2.11.0-dev            1024
# 2485251675           2.11.0-dev              16
# 2582505864           2.11.0-dev             512
# 2587145696           2.11.0-dev               4
# 2594580796           2.11.0-dev               2
# 2618268633           2.11.0-dev             256
# 2626391776           2.11.0-dev               4
# 2637606415           2.11.0-dev              64
# 2639201708           2.11.0-dev               4
# 2669473076           2.11.0-dev              32
# 2704205021           2.11.0-dev            1024
# 2706012724           2.11.0-dev             256
# 2719799638           2.11.0-dev               4
# 2737302455           2.11.0-dev            1024
# 2743877208           2.11.0-dev             256
# 2744417823           2.11.0-dev               2
# 2753158372           2.11.0-dev               4
# 2753724806           2.11.0-dev               2
# 2772609424           2.11.0-dev               2
# 2773050484           2.11.0-dev             512
# 2779226622           2.11.0-dev               2
# 2795167600           2.11.0-dev             128
# 2804866448           2.11.0-dev            1024
# 2831673121           2.11.0-dev              16
# 2862858709           2.11.0-dev               8
# 2886184647           2.11.0-dev              16
# 2893325145           2.11.0-dev             512
# 2899701601           2.11.0-dev             128
# 2908591408           2.11.0-dev              16
# 2940433378           2.11.0-dev              16
# 2946901972           2.11.0-dev              64
# 2965951278           2.11.0-dev            1024
# 3057023798           2.11.0-dev              32
# 3077736110           2.11.0-dev               8
# 3078589478           2.11.0-dev              16
# 3098579292           2.11.0-dev            1024
# 3110591010           2.11.0-dev             128
# 3142709527           2.11.0-dev               4
# 3173294490           2.11.0-dev              64
# 3192008500           2.11.0-dev               8
# 3286481193           2.11.0-dev              64
# 3298896875           2.11.0-dev             512
# 3299761081           2.11.0-dev              64
# 3318007366           2.11.0-dev              16
# 3336902520           2.11.0-dev              64
# 3340143566           2.11.0-dev               2
# 3379292610           2.11.0-dev             512
# 3389909061           2.11.0-dev              32
# 3433755135           2.11.0-dev              64
# 3456508721           2.11.0-dev             128
# 3474736080           2.11.0-dev               4
# 3481449564           2.11.0-dev            1024
# 3485875254           2.11.0-dev             128
# 3554194851           2.11.0-dev              32
# 3556044417           2.11.0-dev              32
# 3630435765           2.11.0-dev               2
# 3647364000           2.11.0-dev               2
# 3661393859           2.11.0-dev               2
# 3673068904           2.11.0-dev               8
# 3691201312           2.11.0-dev              64
# 3716488266           2.11.0-dev              16
# 3737681072           2.11.0-dev             128
# 3741191472           2.11.0-dev               8
# 3745778500           2.11.0-dev               4
# 3746771225           2.11.0-dev             128
# 3784359167           2.11.0-dev              16
# 3864821423           2.11.0-dev            1024
# 3889166710           2.11.0-dev              16
# 3943886424           2.11.0-dev               2
# 3949347486           2.11.0-dev            1024
# 3982384336           2.11.0-dev             128
# 4019004179           2.11.0-dev              16
# 4063709671           2.11.0-dev               4
# 4081015709           2.11.0-dev             128
# 4143420969           2.11.0-dev            1024
# 4147943761           2.11.0-dev              64
# 4174912868           2.11.0-dev              32
# 4252670885           2.11.0-dev              64
# 4254804346           2.11.0-dev               2
#
#                                                  spot.metrics  \
# profile
# 96387453    min#inclusive#sum#time.duration,max#inclusive#...
# 125094042   min#inclusive#sum#time.duration,max#inclusive#...
# 136462064   min#inclusive#sum#time.duration,max#inclusive#...
# 224262369   min#inclusive#sum#time.duration,max#inclusive#...
# 226423909   min#inclusive#sum#time.duration,max#inclusive#...
# 236817265   min#inclusive#sum#time.duration,max#inclusive#...
# 254330487   min#inclusive#sum#time.duration,max#inclusive#...
# 267055606   min#inclusive#sum#time.duration,max#inclusive#...
# 328894138   min#inclusive#sum#time.duration,max#inclusive#...
# 366907904   min#inclusive#sum#time.duration,max#inclusive#...
# 369740256   min#inclusive#sum#time.duration,max#inclusive#...
# 478579561   min#inclusive#sum#time.duration,max#inclusive#...
# 485392475   min#inclusive#sum#time.duration,max#inclusive#...
# 491488988   min#inclusive#sum#time.duration,max#inclusive#...
# 498735902   min#inclusive#sum#time.duration,max#inclusive#...
# 512550339   min#inclusive#sum#time.duration,max#inclusive#...
# 515405417   min#inclusive#sum#time.duration,max#inclusive#...
# 534472231   min#inclusive#sum#time.duration,max#inclusive#...
# 561425512   min#inclusive#sum#time.duration,max#inclusive#...
# 577358404   min#inclusive#sum#time.duration,max#inclusive#...
# 591006971   min#inclusive#sum#time.duration,max#inclusive#...
# 602430384   min#inclusive#sum#time.duration,max#inclusive#...
# 689404126   min#inclusive#sum#time.duration,max#inclusive#...
# 791874404   min#inclusive#sum#time.duration,max#inclusive#...
# 866384639   min#inclusive#sum#time.duration,max#inclusive#...
# 914308246   min#inclusive#sum#time.duration,max#inclusive#...
# 939046943   min#inclusive#sum#time.duration,max#inclusive#...
# 1058089730  min#inclusive#sum#time.duration,max#inclusive#...
# 1063817247  min#inclusive#sum#time.duration,max#inclusive#...
# 1112895243  min#inclusive#sum#time.duration,max#inclusive#...
# 1125817381  min#inclusive#sum#time.duration,max#inclusive#...
# 1127408257  min#inclusive#sum#time.duration,max#inclusive#...
# 1132568813  min#inclusive#sum#time.duration,max#inclusive#...
# 1178857823  min#inclusive#sum#time.duration,max#inclusive#...
# 1208028574  min#inclusive#sum#time.duration,max#inclusive#...
# 1219508416  min#inclusive#sum#time.duration,max#inclusive#...
# 1229844398  min#inclusive#sum#time.duration,max#inclusive#...
# 1233138883  min#inclusive#sum#time.duration,max#inclusive#...
# 1235336969  min#inclusive#sum#time.duration,max#inclusive#...
# 1244749383  min#inclusive#sum#time.duration,max#inclusive#...
# 1252107835  min#inclusive#sum#time.duration,max#inclusive#...
# 1255156828  min#inclusive#sum#time.duration,max#inclusive#...
# 1277230400  min#inclusive#sum#time.duration,max#inclusive#...
# 1285908972  min#inclusive#sum#time.duration,max#inclusive#...
# 1334413436  min#inclusive#sum#time.duration,max#inclusive#...
# 1342788810  min#inclusive#sum#time.duration,max#inclusive#...
# 1354911456  min#inclusive#sum#time.duration,max#inclusive#...
# 1360757312  min#inclusive#sum#time.duration,max#inclusive#...
# 1415354612  min#inclusive#sum#time.duration,max#inclusive#...
# 1452988688  min#inclusive#sum#time.duration,max#inclusive#...
# 1467409442  min#inclusive#sum#time.duration,max#inclusive#...
# 1510749833  min#inclusive#sum#time.duration,max#inclusive#...
# 1514005273  min#inclusive#sum#time.duration,max#inclusive#...
# 1552742471  min#inclusive#sum#time.duration,max#inclusive#...
# 1571739899  min#inclusive#sum#time.duration,max#inclusive#...
# 1594575338  min#inclusive#sum#time.duration,max#inclusive#...
# 1618502310  min#inclusive#sum#time.duration,max#inclusive#...
# 1646947451  min#inclusive#sum#time.duration,max#inclusive#...
# 1688383690  min#inclusive#sum#time.duration,max#inclusive#...
# 1701506829  min#inclusive#sum#time.duration,max#inclusive#...
# 1790927496  min#inclusive#sum#time.duration,max#inclusive#...
# 1798249285  min#inclusive#sum#time.duration,max#inclusive#...
# 1844985577  min#inclusive#sum#time.duration,max#inclusive#...
# 1850520422  min#inclusive#sum#time.duration,max#inclusive#...
# 1898457644  min#inclusive#sum#time.duration,max#inclusive#...
# 1925583792  min#inclusive#sum#time.duration,max#inclusive#...
# 1930022590  min#inclusive#sum#time.duration,max#inclusive#...
# 1941721610  min#inclusive#sum#time.duration,max#inclusive#...
# 1946102318  min#inclusive#sum#time.duration,max#inclusive#...
# 1946591664  min#inclusive#sum#time.duration,max#inclusive#...
# 1947014976  min#inclusive#sum#time.duration,max#inclusive#...
# 1963726364  min#inclusive#sum#time.duration,max#inclusive#...
# 1963771600  min#inclusive#sum#time.duration,max#inclusive#...
# 1993344714  min#inclusive#sum#time.duration,max#inclusive#...
# 2071331326  min#inclusive#sum#time.duration,max#inclusive#...
# 2200548846  min#inclusive#sum#time.duration,max#inclusive#...
# 2202992537  min#inclusive#sum#time.duration,max#inclusive#...
# 2209562025  min#inclusive#sum#time.duration,max#inclusive#...
# 2239031269  min#inclusive#sum#time.duration,max#inclusive#...
# 2243547470  min#inclusive#sum#time.duration,max#inclusive#...
# 2251050041  min#inclusive#sum#time.duration,max#inclusive#...
# 2275966125  min#inclusive#sum#time.duration,max#inclusive#...
# 2299812503  min#inclusive#sum#time.duration,max#inclusive#...
# 2307843172  min#inclusive#sum#time.duration,max#inclusive#...
# 2309438091  min#inclusive#sum#time.duration,max#inclusive#...
# 2338225906  min#inclusive#sum#time.duration,max#inclusive#...
# 2353328152  min#inclusive#sum#time.duration,max#inclusive#...
# 2379841991  min#inclusive#sum#time.duration,max#inclusive#...
# 2385682507  min#inclusive#sum#time.duration,max#inclusive#...
# 2418087398  min#inclusive#sum#time.duration,max#inclusive#...
# 2430489637  min#inclusive#sum#time.duration,max#inclusive#...
# 2485251675  min#inclusive#sum#time.duration,max#inclusive#...
# 2582505864  min#inclusive#sum#time.duration,max#inclusive#...
# 2587145696  min#inclusive#sum#time.duration,max#inclusive#...
# 2594580796  min#inclusive#sum#time.duration,max#inclusive#...
# 2618268633  min#inclusive#sum#time.duration,max#inclusive#...
# 2626391776  min#inclusive#sum#time.duration,max#inclusive#...
# 2637606415  min#inclusive#sum#time.duration,max#inclusive#...
# 2639201708  min#inclusive#sum#time.duration,max#inclusive#...
# 2669473076  min#inclusive#sum#time.duration,max#inclusive#...
# 2704205021  min#inclusive#sum#time.duration,max#inclusive#...
# 2706012724  min#inclusive#sum#time.duration,max#inclusive#...
# 2719799638  min#inclusive#sum#time.duration,max#inclusive#...
# 2737302455  min#inclusive#sum#time.duration,max#inclusive#...
# 2743877208  min#inclusive#sum#time.duration,max#inclusive#...
# 2744417823  min#inclusive#sum#time.duration,max#inclusive#...
# 2753158372  min#inclusive#sum#time.duration,max#inclusive#...
# 2753724806  min#inclusive#sum#time.duration,max#inclusive#...
# 2772609424  min#inclusive#sum#time.duration,max#inclusive#...
# 2773050484  min#inclusive#sum#time.duration,max#inclusive#...
# 2779226622  min#inclusive#sum#time.duration,max#inclusive#...
# 2795167600  min#inclusive#sum#time.duration,max#inclusive#...
# 2804866448  min#inclusive#sum#time.duration,max#inclusive#...
# 2831673121  min#inclusive#sum#time.duration,max#inclusive#...
# 2862858709  min#inclusive#sum#time.duration,max#inclusive#...
# 2886184647  min#inclusive#sum#time.duration,max#inclusive#...
# 2893325145  min#inclusive#sum#time.duration,max#inclusive#...
# 2899701601  min#inclusive#sum#time.duration,max#inclusive#...
# 2908591408  min#inclusive#sum#time.duration,max#inclusive#...
# 2940433378  min#inclusive#sum#time.duration,max#inclusive#...
# 2946901972  min#inclusive#sum#time.duration,max#inclusive#...
# 2965951278  min#inclusive#sum#time.duration,max#inclusive#...
# 3057023798  min#inclusive#sum#time.duration,max#inclusive#...
# 3077736110  min#inclusive#sum#time.duration,max#inclusive#...
# 3078589478  min#inclusive#sum#time.duration,max#inclusive#...
# 3098579292  min#inclusive#sum#time.duration,max#inclusive#...
# 3110591010  min#inclusive#sum#time.duration,max#inclusive#...
# 3142709527  min#inclusive#sum#time.duration,max#inclusive#...
# 3173294490  min#inclusive#sum#time.duration,max#inclusive#...
# 3192008500  min#inclusive#sum#time.duration,max#inclusive#...
# 3286481193  min#inclusive#sum#time.duration,max#inclusive#...
# 3298896875  min#inclusive#sum#time.duration,max#inclusive#...
# 3299761081  min#inclusive#sum#time.duration,max#inclusive#...
# 3318007366  min#inclusive#sum#time.duration,max#inclusive#...
# 3336902520  min#inclusive#sum#time.duration,max#inclusive#...
# 3340143566  min#inclusive#sum#time.duration,max#inclusive#...
# 3379292610  min#inclusive#sum#time.duration,max#inclusive#...
# 3389909061  min#inclusive#sum#time.duration,max#inclusive#...
# 3433755135  min#inclusive#sum#time.duration,max#inclusive#...
# 3456508721  min#inclusive#sum#time.duration,max#inclusive#...
# 3474736080  min#inclusive#sum#time.duration,max#inclusive#...
# 3481449564  min#inclusive#sum#time.duration,max#inclusive#...
# 3485875254  min#inclusive#sum#time.duration,max#inclusive#...
# 3554194851  min#inclusive#sum#time.duration,max#inclusive#...
# 3556044417  min#inclusive#sum#time.duration,max#inclusive#...
# 3630435765  min#inclusive#sum#time.duration,max#inclusive#...
# 3647364000  min#inclusive#sum#time.duration,max#inclusive#...
# 3661393859  min#inclusive#sum#time.duration,max#inclusive#...
# 3673068904  min#inclusive#sum#time.duration,max#inclusive#...
# 3691201312  min#inclusive#sum#time.duration,max#inclusive#...
# 3716488266  min#inclusive#sum#time.duration,max#inclusive#...
# 3737681072  min#inclusive#sum#time.duration,max#inclusive#...
# 3741191472  min#inclusive#sum#time.duration,max#inclusive#...
# 3745778500  min#inclusive#sum#time.duration,max#inclusive#...
# 3746771225  min#inclusive#sum#time.duration,max#inclusive#...
# 3784359167  min#inclusive#sum#time.duration,max#inclusive#...
# 3864821423  min#inclusive#sum#time.duration,max#inclusive#...
# 3889166710  min#inclusive#sum#time.duration,max#inclusive#...
# 3943886424  min#inclusive#sum#time.duration,max#inclusive#...
# 3949347486  min#inclusive#sum#time.duration,max#inclusive#...
# 3982384336  min#inclusive#sum#time.duration,max#inclusive#...
# 4019004179  min#inclusive#sum#time.duration,max#inclusive#...
# 4063709671  min#inclusive#sum#time.duration,max#inclusive#...
# 4081015709  min#inclusive#sum#time.duration,max#inclusive#...
# 4143420969  min#inclusive#sum#time.duration,max#inclusive#...
# 4147943761  min#inclusive#sum#time.duration,max#inclusive#...
# 4174912868  min#inclusive#sum#time.duration,max#inclusive#...
# 4252670885  min#inclusive#sum#time.duration,max#inclusive#...
# 4254804346  min#inclusive#sum#time.duration,max#inclusive#...
#
#            spot.timeseries.metrics  spot.format.version  \
# profile
#
# 3691201312                                            2
# 3716488266                                            2
# 3737681072                                            2
# 3741191472                                            2
# 3745778500                                            2
# 3746771225                                            2
# 3784359167                                            2
# 3864821423                                            2
# 3889166710                                            2
# 3943886424                                            2
# 3949347486                                            2
# 3982384336                                            2
# 4019004179                                            2
# 4063709671                                            2
# 4081015709                                            2
# 4143420969                                            2
# 4147943761                                            2
# 4174912868                                            2
# 4252670885                                            2
# 4254804346                                            2
#
#                         spot.options  spot.channels cali.channel  \
# profile
# 96387453    time.variance,node.order  regionprofile         spot
# 125094042   time.variance,node.order  regionprofile         spot
# 136462064   time.variance,node.order  regionprofile         spot
# 224262369   time.variance,node.order  regionprofile         spot
# 226423909   time.variance,node.order  regionprofile         spot
# 236817265   time.variance,node.order  regionprofile         spot
# 254330487   time.variance,node.order  regionprofile         spot
# 267055606   time.variance,node.order  regionprofile         spot
# 328894138   time.variance,node.order  regionprofile         spot
# 366907904   time.variance,node.order  regionprofile         spot
# 369740256   time.variance,node.order  regionprofile         spot
# 478579561   time.variance,node.order  regionprofile         spot
# 485392475   time.variance,node.order  regionprofile         spot
# 491488988   time.variance,node.order  regionprofile         spot
# 498735902   time.variance,node.order  regionprofile         spot
# 512550339   time.variance,node.order  regionprofile         spot
# 515405417   time.variance,node.order  regionprofile         spot
# 534472231   time.variance,node.order  regionprofile         spot
# 561425512   time.variance,node.order  regionprofile         spot
# 577358404   time.variance,node.order  regionprofile         spot
# 591006971   time.variance,node.order  regionprofile         spot
# 602430384   time.variance,node.order  regionprofile         spot
# 689404126   time.variance,node.order  regionprofile         spot
# 791874404   time.variance,node.order  regionprofile         spot
# 866384639   time.variance,node.order  regionprofile         spot
# 914308246   time.variance,node.order  regionprofile         spot
# 939046943   time.variance,node.order  regionprofile         spot
# 1058089730  time.variance,node.order  regionprofile         spot
# 1063817247  time.variance,node.order  regionprofile         spot
# 1112895243  time.variance,node.order  regionprofile         spot
# 1125817381  time.variance,node.order  regionprofile         spot
# 1127408257  time.variance,node.order  regionprofile         spot
# 1132568813  time.variance,node.order  regionprofile         spot
# 1178857823  time.variance,node.order  regionprofile         spot
# 1208028574  time.variance,node.order  regionprofile         spot
# 1219508416  time.variance,node.order  regionprofile         spot
# 1229844398  time.variance,node.order  regionprofile         spot
# 1233138883  time.variance,node.order  regionprofile         spot
# 1235336969  time.variance,node.order  regionprofile         spot
# 1244749383  time.variance,node.order  regionprofile         spot
# 1252107835  time.variance,node.order  regionprofile         spot
# 1255156828  time.variance,node.order  regionprofile         spot
# 1277230400  time.variance,node.order  regionprofile         spot
# 1285908972  time.variance,node.order  regionprofile         spot
# 1334413436  time.variance,node.order  regionprofile         spot
# 1342788810  time.variance,node.order  regionprofile         spot
# 1354911456  time.variance,node.order  regionprofile         spot
# 1360757312  time.variance,node.order  regionprofile         spot
# 1415354612  time.variance,node.order  regionprofile         spot
# 1452988688  time.variance,node.order  regionprofile         spot
# 1467409442  time.variance,node.order  regionprofile         spot
# 1510749833  time.variance,node.order  regionprofile         spot
# 1514005273  time.variance,node.order  regionprofile         spot
# 1552742471  time.variance,node.order  regionprofile         spot
# 1571739899  time.variance,node.order  regionprofile         spot
# 1594575338  time.variance,node.order  regionprofile         spot
# 1618502310  time.variance,node.order  regionprofile         spot
# 1646947451  time.variance,node.order  regionprofile         spot
# 1688383690  time.variance,node.order  regionprofile         spot
# 1701506829  time.variance,node.order  regionprofile         spot
# 1790927496  time.variance,node.order  regionprofile         spot
# 1798249285  time.variance,node.order  regionprofile         spot
# 1844985577  time.variance,node.order  regionprofile         spot
# 1850520422  time.variance,node.order  regionprofile         spot
# 1898457644  time.variance,node.order  regionprofile         spot
# 1925583792  time.variance,node.order  regionprofile         spot
# 1930022590  time.variance,node.order  regionprofile         spot
# 1941721610  time.variance,node.order  regionprofile         spot
# 1946102318  time.variance,node.order  regionprofile         spot
# 1946591664  time.variance,node.order  regionprofile         spot
# 1947014976  time.variance,node.order  regionprofile         spot
# 1963726364  time.variance,node.order  regionprofile         spot
# 1963771600  time.variance,node.order  regionprofile         spot
# 1993344714  time.variance,node.order  regionprofile         spot
# 2071331326  time.variance,node.order  regionprofile         spot
# 2200548846  time.variance,node.order  regionprofile         spot
# 2202992537  time.variance,node.order  regionprofile         spot
# 2209562025  time.variance,node.order  regionprofile         spot
# 2239031269  time.variance,node.order  regionprofile         spot
# 2243547470  time.variance,node.order  regionprofile         spot
# 2251050041  time.variance,node.order  regionprofile         spot
# 2275966125  time.variance,node.order  regionprofile         spot
# 2299812503  time.variance,node.order  regionprofile         spot
# 2307843172  time.variance,node.order  regionprofile         spot
# 2309438091  time.variance,node.order  regionprofile         spot
# 2338225906  time.variance,node.order  regionprofile         spot
# 2353328152  time.variance,node.order  regionprofile         spot
# 2379841991  time.variance,node.order  regionprofile         spot
# 2385682507  time.variance,node.order  regionprofile         spot
# 2418087398  time.variance,node.order  regionprofile         spot
# 2430489637  time.variance,node.order  regionprofile         spot
# 2485251675  time.variance,node.order  regionprofile         spot
# 2582505864  time.variance,node.order  regionprofile         spot
# 2587145696  time.variance,node.order  regionprofile         spot
# 2594580796  time.variance,node.order  regionprofile         spot
# 2618268633  time.variance,node.order  regionprofile         spot
# 2626391776  time.variance,node.order  regionprofile         spot
# 2637606415  time.variance,node.order  regionprofile         spot
# 2639201708  time.variance,node.order  regionprofile         spot
# 2669473076  time.variance,node.order  regionprofile         spot
# 2704205021  time.variance,node.order  regionprofile         spot
# 2706012724  time.variance,node.order  regionprofile         spot
# 2719799638  time.variance,node.order  regionprofile         spot
# 2737302455  time.variance,node.order  regionprofile         spot
# 2743877208  time.variance,node.order  regionprofile         spot
# 2744417823  time.variance,node.order  regionprofile         spot
# 2753158372  time.variance,node.order  regionprofile         spot
# 2753724806  time.variance,node.order  regionprofile         spot
# 2772609424  time.variance,node.order  regionprofile         spot
# 2773050484  time.variance,node.order  regionprofile         spot
# 2779226622  time.variance,node.order  regionprofile         spot
# 2795167600  time.variance,node.order  regionprofile         spot
# 2804866448  time.variance,node.order  regionprofile         spot
# 2831673121  time.variance,node.order  regionprofile         spot
# 2862858709  time.variance,node.order  regionprofile         spot
# 2886184647  time.variance,node.order  regionprofile         spot
# 2893325145  time.variance,node.order  regionprofile         spot
# 2899701601  time.variance,node.order  regionprofile         spot
# 2908591408  time.variance,node.order  regionprofile         spot
# 2940433378  time.variance,node.order  regionprofile         spot
# 2946901972  time.variance,node.order  regionprofile         spot
# 2965951278  time.variance,node.order  regionprofile         spot
# 3057023798  time.variance,node.order  regionprofile         spot
# 3077736110  time.variance,node.order  regionprofile         spot
# 3078589478  time.variance,node.order  regionprofile         spot
# 3098579292  time.variance,node.order  regionprofile         spot
# 3110591010  time.variance,node.order  regionprofile         spot
# 3142709527  time.variance,node.order  regionprofile         spot
# 3173294490  time.variance,node.order  regionprofile         spot
# 3192008500  time.variance,node.order  regionprofile         spot
# 3286481193  time.variance,node.order  regionprofile         spot
# 3298896875  time.variance,node.order  regionprofile         spot
# 3299761081  time.variance,node.order  regionprofile         spot
# 3318007366  time.variance,node.order  regionprofile         spot
# 3336902520  time.variance,node.order  regionprofile         spot
# 3340143566  time.variance,node.order  regionprofile         spot
# 3379292610  time.variance,node.order  regionprofile         spot
# 3389909061  time.variance,node.order  regionprofile         spot
# 3433755135  time.variance,node.order  regionprofile         spot
# 3456508721  time.variance,node.order  regionprofile         spot
# 3474736080  time.variance,node.order  regionprofile         spot
# 3481449564  time.variance,node.order  regionprofile         spot
# 3485875254  time.variance,node.order  regionprofile         spot
# 3554194851  time.variance,node.order  regionprofile         spot
# 3556044417  time.variance,node.order  regionprofile         spot
# 3630435765  time.variance,node.order  regionprofile         spot
# 3647364000  time.variance,node.order  regionprofile         spot
# 3661393859  time.variance,node.order  regionprofile         spot
# 3673068904  time.variance,node.order  regionprofile         spot
# 3691201312  time.variance,node.order  regionprofile         spot
# 3716488266  time.variance,node.order  regionprofile         spot
# 3737681072  time.variance,node.order  regionprofile         spot
# 3741191472  time.variance,node.order  regionprofile         spot
# 3745778500  time.variance,node.order  regionprofile         spot
# 3746771225  time.variance,node.order  regionprofile         spot
# 3784359167  time.variance,node.order  regionprofile         spot
# 3864821423  time.variance,node.order  regionprofile         spot
# 3889166710  time.variance,node.order  regionprofile         spot
# 3943886424  time.variance,node.order  regionprofile         spot
# 3949347486  time.variance,node.order  regionprofile         spot
# 3982384336  time.variance,node.order  regionprofile         spot
# 4019004179  time.variance,node.order  regionprofile         spot
# 4063709671  time.variance,node.order  regionprofile         spot
# 4081015709  time.variance,node.order  regionprofile         spot
# 4143420969  time.variance,node.order  regionprofile         spot
# 4147943761  time.variance,node.order  regionprofile         spot
# 4174912868  time.variance,node.order  regionprofile         spot
# 4252670885  time.variance,node.order  regionprofile         spot
# 4254804346  time.variance,node.order  regionprofile         spot
#
#            spot:node.order                      spot:output  \
# profile
# 96387453              true           262144-8-3-bubble.cali
# 125094042             true        67108864-64-3-sample.cali
# 136462064             true       1048576-1024-3-sample.cali
# 224262369             true           262144-8-3-sample.cali
# 226423909             true            65536-8-3-bubble.cali
# 236817265             true     1048576-256-3-mergesort.cali
# 1963771600            true           65536-16-3-bubble.cali
# 1993344714            true         65536-1024-3-sample.cali
# 2071331326            true      268435456-128-3-sample.cali
# 2200548846            true         65536-1024-3-bubble.cali
# 2202992537            true         262144-128-3-sample.cali
# 2209562025            true   268435456-256-3-mergesort.cali
# 2239031269            true        262144-1024-3-sample.cali
# 2243547470            true      16777216-8-3-mergesort.cali
# 2251050041            true        4194304-256-3-sample.cali
# 2275966125            true          4194304-4-3-sample.cali
# 2299812503            true          1048576-8-3-sample.cali
# 2307843172            true          65536-256-3-bubble.cali
# 2309438091            true         262144-512-3-sample.cali
# 2338225906            true     16777216-16-3-mergesort.cali
# 2353328152            true      262144-128-3-mergesort.cali
# 2379841991            true        16777216-16-3-sample.cali
# 2385682507            true      67108864-8-3-mergesort.cali
# 2418087398            true         16777216-2-3-sample.cali
# 2430489637            true        262144-1024-3-bubble.cali
# 2485251675            true      4194304-16-3-mergesort.cali
# 2582505864            true      268435456-512-3-sample.cali
# 2587145696            true      67108864-4-3-mergesort.cali
# 2594580796            true         65536-2-3-mergesort.cali
# 2618268633            true      268435456-256-3-sample.cali
# 2626391776            true        262144-4-3-mergesort.cali
# 2637606415            true      4194304-64-3-mergesort.cali
# 2639201708            true         16777216-4-3-sample.cali
# 2669473076            true          262144-32-3-bubble.cali
# ...
# 2338225906         16           16        N/A         14
# 2353328152        128          128        N/A         14
# 2379841991         16            0        NaN         14
# 2385682507          8            8        N/A         14
# 2418087398          2            0        NaN         14
# 2430489637       1024            0        NaN         14
# 2485251675         16           16        N/A         14
# 2582505864        512            0        NaN         14
# 2587145696          4            4        N/A         14
# 2594580796          2            2        N/A         14
# 2618268633        256            0        NaN         14
# 2626391776          4            4        N/A         14
# 2637606415         64           64        N/A         14
# 2639201708          4            0        NaN         14
# 2669473076         32            0        NaN         14
# 2704205021       1024         1024        N/A         14
# 2706012724        256            0        NaN         14
# 2719799638          4            4        N/A         14
# 2737302455       1024         1024        N/A         14
# 2743877208        256            0        NaN         14
# 2744417823          2            0        NaN         14
# 2753158372          4            0        NaN         14
# 2753724806          2            2        N/A         14
# 2772609424          2            0        NaN         14
# 2773050484        512            0        NaN         14
# 2779226622          2            2        N/A         14
# 2795167600        128          128        N/A         14
# 2804866448       1024            0        NaN         14
# 2831673121         16           16        N/A         14
# 2862858709          8            8        N/A         14
# 2886184647         16           16        N/A         14
# 2893325145        512            0        NaN         14
# 2899701601        128            0        NaN         14
# 2908591408         16           16        N/A         14
# 2940433378         16            0        NaN         14
# 2946901972         64            0        NaN         14
# 2965951278       1024         1024        N/A         14
# 3057023798         32            0        NaN         14
# 3077736110          8            0        NaN         14
# 3078589478         16            0        NaN         14
# 3098579292       1024            0        NaN         14
# 3110591010        128            0        NaN         14
# 3142709527          4            0        NaN         14
# 3173294490         64            0        NaN         14
# 3192008500          8            8        N/A         14
# 3286481193         64            0        NaN         14
# 3298896875        512          512        N/A         14
# 3299761081         64           64        N/A         14
# 3318007366         16            0        NaN         14
# 3336902520         64            0        NaN         14
# 3340143566          2            2        N/A         14
# 3379292610        512            0        NaN         14
# 3389909061         32           32        N/A         14
# 3433755135         64           64        N/A         14
# 3456508721        128          128        N/A         14
# 3474736080          4            0        NaN         14
# 3481449564       1024         1024        N/A         14
# 3485875254        128            0        NaN         14
# 3554194851         32            0        NaN         14
# 3556044417         32           32        N/A         14
# 3630435765          2            0        NaN         14
# 3647364000          2            0        NaN         14
# 3661393859          2            0        NaN         14
# 3673068904          8            8        N/A         14
# 3691201312         64            0        NaN         14
# 3716488266         16            0        NaN         14
# 3737681072        128          128        N/A         14
# 3741191472          8            8        N/A         14
# 3745778500          4            0        NaN         14
# 3746771225        128            0        NaN         14
# 3784359167         16            0        NaN         14
# 3864821423       1024            0        NaN         14
# 3889166710         16            0        NaN         14
# 3943886424          2            0        NaN         14
# 3949347486       1024            0        NaN         14
# 3982384336        128            0        NaN         14
# 4019004179         16           16        N/A         14
# 4063709671          4            0        NaN         14
# 4081015709        128          128        N/A         14
# 4143420969       1024         1024        N/A         14
# 4147943761         64           64        N/A         14
# 4174912868         32           32        N/A         14
# 4252670885         64            0        NaN         14
# 4254804346          2            0        NaN         14
#
#            implementation_source correctness  values_per_proc
# profile
# 96387453             Handwritten     success            32768
# 125094042            Handwritten     success          1048576
# 136462064            Handwritten     success             1024
# 224262369            Handwritten     success            32768
# 226423909            Handwritten     success             8192
# 236817265                 Online         NaN             4096
# 254330487            Handwritten     success           524288
# 267055606            Handwritten     success             1024
# 328894138            Handwritten     success           262144
# 366907904                 Online         NaN             8192
# 369740256                 Online         NaN           524288
# 478579561                 Online         NaN              256
# 485392475            Handwritten     success              512
# 491488988                 Online         NaN           131072
# 498735902            Handwritten     success            32768
# 512550339            Handwritten     success           131072
# 515405417            Handwritten     success           524288
# 534472231                 Online         NaN           131072
# 561425512                 Online         NaN            32768
# 577358404            Handwritten     success             4096
# 591006971                 Online         NaN             2048
# 602430384            Handwritten     success             2048
# 689404126                 Online         NaN            16384
# 791874404            Handwritten     success             8192
# 866384639            Handwritten     success           131072
# 914308246                 Online         NaN              512
# 939046943                 Online         NaN              512
# 1058089730                Online         NaN           131072
# 1063817247                Online         NaN          4194304
# 1112895243           Handwritten     success           262144
# 1125817381           Handwritten     success            32768
# 1127408257                Online         NaN            16384
# 1132568813           Handwritten     success              128
# 1178857823           Handwritten     success           524288
# 1208028574           Handwritten     success            65536
# 1219508416           Handwritten     success           524288
# 1229844398           Handwritten     success              512
# 1233138883           Handwritten     success          2097152
# 1235336969           Handwritten     success            32768
# 1244749383           Handwritten     success          2097152
# 1252107835           Handwritten     success            16384
# 1255156828           Handwritten     success            16384
# 1277230400           Handwritten     success             4096
# 1285908972                Online         NaN           131072
# 1334413436           Handwritten     success            32768
# 1342788810                Online         NaN          1048576
# 1354911456                Online         NaN            16384
# 1360757312                Online         NaN             1024
# 1415354612                Online         NaN             8192
# 1452988688           Handwritten     success         16777216
# 1467409442                Online         NaN            32768
# 1510749833           Handwritten     success            16384
# 1514005273                Online         NaN            16384
# 1552742471           Handwritten     success         33554432
# 1571739899                Online         NaN            32768
# 1594575338           Handwritten     success             1024
# 1618502310                Online         NaN          8388608
# 1646947451           Handwritten     success            65536
# 1688383690                Online         NaN          4194304
# 1701506829                Online         NaN               64
# 1790927496                Online         NaN          1048576
# 1798249285                Online         NaN            65536
# 1844985577           Handwritten     success             8192
# 1850520422                Online         NaN           262144
# 1898457644           Handwritten     success             2048
# 1925583792           Handwritten     success          8388608
# 1930022590                Online         NaN             1024
# 1941721610                Online         NaN          8388608
# 1946102318                Online         NaN         67108864
# 1946591664                Online         NaN        134217728
# 1947014976           Handwritten     success            65536
# 1963726364           Handwritten     success            65536
# 1963771600           Handwritten     success             4096
# 1993344714           Handwritten     success               64
# 2071331326           Handwritten     success          2097152
# 2200548846           Handwritten     success               64
# 2202992537           Handwritten     success             2048
# 2209562025                Online         NaN          1048576
# 2239031269           Handwritten     success              256
# 2243547470                Online         NaN          2097152
# 2251050041           Handwritten     success            16384
# 2275966125           Handwritten     success          1048576
# 2299812503           Handwritten     success           131072
# 2307843172           Handwritten     success              256
# 2309438091           Handwritten     success              512
# 2338225906                Online         NaN          1048576
# 2353328152                Online         NaN             2048
# 2379841991           Handwritten     success          1048576
# 2385682507                Online         NaN          8388608
# 2418087398           Handwritten     success          8388608
# 2430489637           Handwritten     success              256
# 2485251675                Online         NaN           262144
# 2582505864           Handwritten     success           524288
# 2587145696                Online         NaN         16777216
# 2594580796                Online         NaN            32768
# 2618268633           Handwritten     success          1048576
# 2626391776                Online         NaN            65536
# 2637606415                Online         NaN            65536
# 2639201708           Handwritten     success          4194304
# 2669473076           Handwritten     success             8192
# 2704205021                Online         NaN           262144
# 2706012724           Handwritten     success              256
# 2719799638                Online         NaN           262144
# 2737302455                Online         NaN            65536
# 2743877208           Handwritten     success             1024
# 2744417823           Handwritten     success            32768
# 2753158372           Handwritten     success         67108864
# 2753724806                Online         NaN         33554432
# 2772609424           Handwritten     success           524288
# 2773050484           Handwritten     success              128
# 2779226622                Online         NaN          2097152
# 2795167600                Online         NaN             8192
# 2804866448           Handwritten     success             4096
# 2831673121                Online         NaN            65536
# 2862858709                Online         NaN           524288
# 2886184647                Online         NaN             4096
# 2893325145           Handwritten     success             2048
# 2899701601           Handwritten     success             8192
# 2908591408                Online         NaN          4194304
# 2940433378           Handwritten     success          4194304
# 2946901972           Handwritten     success            16384
# 2965951278                Online         NaN              256
# 3057023798           Handwritten     success            32768
# 3077736110           Handwritten     success             8192
# 3078589478           Handwritten     success         16777216
# 3098579292           Handwritten     success            65536
# 3110591010           Handwritten     success           131072
# 3142709527           Handwritten     success            16384
# 3173294490           Handwritten     success             4096
# 3192008500                Online         NaN             8192
# 3286481193           Handwritten     success          4194304
# 3298896875                Online         NaN              128
# 3299761081                Online         NaN           262144
# 3318007366           Handwritten     success            65536
# 3336902520           Handwritten     success             1024
# 3340143566                Online         NaN           524288
# 3379292610           Handwritten     success           131072
# 3389909061                Online         NaN             2048
# 3433755135                Online         NaN             1024
# 3456508721                Online         NaN           524288
# 3474736080           Handwritten     success            65536
# 3481449564                Online         NaN             4096
# 3485875254           Handwritten     success             8192
# 3554194851           Handwritten     success          8388608
# 3556044417                Online         NaN          2097152
# 3630435765           Handwritten     success           131072
# 3647364000           Handwritten     success        134217728
# 3661393859           Handwritten     success         33554432
# 3673068904                Online         NaN         33554432
# 3691201312           Handwritten     success             4096
# 3716488266           Handwritten     success           262144
# 3737681072                Online         NaN          2097152
# 3741191472                Online         NaN            32768
# 3745778500           Handwritten     success           262144
# 3746771225           Handwritten     success             2048
# 3784359167           Handwritten     success            16384
# 3864821423           Handwritten     success             1024
# 3889166710           Handwritten     success             4096
# 3943886424           Handwritten     success          2097152
# 3949347486           Handwritten     success            16384
# 3982384336           Handwritten     success              512
# 4019004179                Online         NaN         16777216
# 4063709671           Handwritten     success           262144
# 4081015709                Online         NaN           131072
# 4143420969                Online         NaN            16384
# 4147943761                Online         NaN             4096
# 4174912868                Online         NaN           524288
# 4252670885           Handwritten     success           262144
# 4254804346           Handwritten     success           131072

# %%
tks.keys()
# Out:
# dict_keys(['mpi_sorted', 'mpi_reverse', 'mpi_random', 'mpi_perturbed'])

# %%
gbs = {}

for i in tks.keys():
    if "mpi" in i:
        gbs[i + "_strong"] = tks[i].groupby("InputSize")
        gbs[i + "_weak"] = tks[i].groupby("values_per_proc")
    else:
        gbs[i + "_strong"] = tks[i].groupby("InputSize")
        gbs[i + "_weak"] = tks[i].groupby("num_blocks")
# Out:
# 8  thickets created...
# {65536: <thicket.thicket.Thicket object at 0x2b4b58cca9d0>, 262144: <thicket.thicket.Thicket object at 0x2b4b58da68e0>, 1048576: <thicket.thicket.Thicket object at 0x2b4b58da1850>, 4194304: <thicket.thicket.Thicket object at 0x2b4b5912c5b0>, 16777216: <thicket.thicket.Thicket object at 0x2b4b5911a2b0>, 67108864: <thicket.thicket.Thicket object at 0x2b4b5910b460>, 167772216: <thicket.thicket.Thicket object at 0x2b4b5911a790>, 268435456: <thicket.thicket.Thicket object at 0x2b4b590daf70>}
# 23  thickets created...
# {64: <thicket.thicket.Thicket object at 0x2b4b58c09d30>, 128: <thicket.thicket.Thicket object at 0x2b4b58c09b80>, 256: <thicket.thicket.Thicket object at 0x2b4b58e14af0>, 512: <thicket.thicket.Thicket object at 0x2b4b591e83d0>, 1024: <thicket.thicket.Thicket object at 0x2b4b591e0730>, 2048: <thicket.thicket.Thicket object at 0x2b4b590b6610>, 4096: <thicket.thicket.Thicket object at 0x2b4b58646850>, 8192: <thicket.thicket.Thicket object at 0x2b4b590b65b0>, 16384: <thicket.thicket.Thicket object at 0x2b4b58fa14f0>, 32768: <thicket.thicket.Thicket object at 0x2b4b58963f40>, 65536: <thicket.thicket.Thicket object at 0x2b4b58f4fd60>, 131072: <thicket.thicket.Thicket object at 0x2b4b58890610>, 262144: <thicket.thicket.Thicket object at 0x2b4b57e3cd60>, 524288: <thicket.thicket.Thicket object at 0x2b4b57e3cdc0>, 1048576: <thicket.thicket.Thicket object at 0x2b4b5878d190>, 1310720: <thicket.thicket.Thicket object at 0x2b4b58733df0>, 2097152: <thicket.thicket.Thicket object
# %% [markdown]
# Compose these 3 groups column-wise to get a holistic view of the data

# %%
print(gbs.keys())
# Out:
# dict_keys(['mpi_sorted_strong', 'mpi_sorted_weak', 'mpi_reverse_strong', 'mpi_reverse_weak', 'mpi_random_strong', 'mpi_random_weak', 'mpi_perturbed_strong', 'mpi_perturbed_weak'])

# %%
ctks = {}

for i in gbs.keys():
#     if "strong" in i:
    if "mpi" in i:
        ctks[i] = th.Thicket.concat_thickets(
            thickets=list(gbs[i].values()),
            headers=list(gbs[i].keys()),
            axis="columns",
            metadata_key="num_procs"
        )
    else:
        ctks[i] = th.Thicket.concat_thickets(
            thickets=list(gbs[i].values()),
            headers=list(gbs[i].keys()),
            axis="columns",
            metadata_key="num_threads"
        )
# Out:
# ---------------------------------------------------------------------------
# InvalidIndexError                         Traceback (most recent call last)
# <ipython-input-20-3e9ba4e1b375> in <module>
#       4 #     if "strong" in i:
#       5     if "mpi" in i:
# ----> 6         ctks[i] = th.Thicket.concat_thickets(
#       7             thickets=list(gbs[i].values()),
#       8             headers=list(gbs[i].keys()),
#
# /scratch/group/csce435-f23/thicket/thicket/thicket.py in concat_thickets(thickets, axis, calltree, **kwargs)
#     322             ct = _index(thickets, **kwargs)
#     323         elif axis == "columns":
# --> 324             ct = _columns(thickets, **kwargs)
#     325         else:
#     326             raise ValueError("axis must be 'index' or 'columns'")
#
# /scratch/group/csce435-f23/thicket/thicket/thicket.py in _columns(thickets, headers, metadata_key)
#     310
#     311         def _columns(thickets, headers=None, metadata_key=None):
# --> 312             combined_thicket = Ensemble._columns(
#     313                 thickets=thickets, headers=headers, metadata_key=metadata_key
#     314             )
#
# /scratch/group/csce435-f23/thicket/thicket/ensemble.py in _columns(thickets, headers, metadata_key)
#     279
#     280         # Step 2A: Handle performance data tables
# --> 281         new_mappings = _handle_perfdata()
#     282         # Step 2B: Handle metadata tables
#     283         _handle_metadata()
#
# /scratch/group/csce435-f23/thicket/thicket/ensemble.py in _handle_perfdata()
#     238
#     239             # Concat performance data table together
# --> 240             combined_th.dataframe = pd.concat(
#     241                 [thickets_cp[i].dataframe for i in range(len(thickets_cp))],
#     242                 axis="columns",
#
# /scratch/group/csce435-f23/python-3.8.17/lib/python3.8/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     383     )
#     384
# --> 385     return op.get_result()
#     386
#     387
#
# /scratch/group/csce435-f23/python-3.8.17/lib/python3.8/site-packages/pandas/core/reshape/concat.py in get_result(self)
#     610                     obj_labels = obj.axes[1 - ax]
#     611                     if not new_labels.equals(obj_labels):
# --> 612                         indexers[ax] = obj_labels.get_indexer(new_labels)
#     613
#     614                 mgrs_indexers.append((obj._mgr, indexers))
#
# /scratch/group/csce435-f23/python-3.8.17/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_indexer(self, target, method, limit, tolerance)
#    3730
#    3731         if not self._index_as_unique:
# -> 3732             raise InvalidIndexError(self._requires_unique_msg)
#    3733
#    3734         if len(target) == 0:
#
# InvalidIndexError: Reindexing only valid with uniquely valued Index objects

# %%
valsPerProcList = ctks["mpi_random_weak"].dataframe.columns.get_level_values(0).unique().drop("name")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-3007f16c87b0> in <module>
# ----> 1 valsPerProcList = ctks["mpi_random_weak"].dataframe.columns.get_level_values(0).unique().drop("name")
#
# KeyError: 'mpi_random_weak'

# %%
valsPerBlockList = ctks["cuda_random_weak"].dataframe.columns.get_level_values(0).unique().drop("name")

# %% [markdown]
# Perform pandas operations to get the table in a desirable format for plotting

# %%
for i in ctks.keys():
    if "cuda" in i:
        if "strong" in i:
            for inputSize in [32768, 65536, 131072, 262144, 524288, 1048576, 2097152]:
                ctks[i].dataframe = ctks[i].dataframe.drop([(inputSize, "nid"), (inputSize, "spot.channel")], axis=1)
            ctks[i].dataframe = ctks[i].dataframe.reset_index().drop([("node", "")], axis=1)
            ctks[i].dataframe = ctks[i].dataframe.rename({("name", ""): "name", ("num_threads", ""): "num_threads"}).set_index(["name", "num_threads"])

        else:
            for valPerBlock in valsPerBlockList: #[32768, 65536, 131072, 262144, 524288, 1048576, 2097152]:
                ctks[i].dataframe = ctks[i].dataframe.drop([(valPerBlock, "nid"), (valPerBlock, "spot.channel")], axis=1)
            ctks[i].dataframe = ctks[i].dataframe.reset_index().drop([("node", "")], axis=1)
            ctks[i].dataframe = ctks[i].dataframe.rename({("name", ""): "name", ("num_threads", ""): "num_threads"}).set_index(["name", "num_threads"])

    else:
        if "strong" in i:
            for inputSize in [65536, 262144, 1048576, 4194304, 16777216, 67108864, 268435456]:
                ctks[i].dataframe = ctks[i].dataframe.drop([(inputSize, "nid"), (inputSize, "spot.channel")], axis=1)

            ctks[i].dataframe = ctks[i].dataframe.reset_index().drop([("node", "")], axis=1)
            ctks[i].dataframe = ctks[i].dataframe.rename({("name", ""): "name", ("num_procs", ""): "num_procs"}).set_index(["name", "num_procs"])
            
        else: 
            for valPerProc in valsPerProcList: #[65536, 262144, 1048576, 4194304, 16777216, 67108864, 268435456]:
                ctks[i].dataframe = ctks[i].dataframe.drop([(valPerProc, "nid"), (valPerProc, "spot.channel")], axis=1)

            ctks[i].dataframe = ctks[i].dataframe.reset_index().drop([("node", "")], axis=1)
            ctks[i].dataframe = ctks[i].dataframe.rename({("name", ""): "name", ("num_procs", ""): "num_procs"}).set_index(["name", "num_procs"])

# %%
ctks["cuda_sorted_weak"].dataframe

# %% [markdown]
# # Plotting

# %% [markdown]
# ### Option 1
# Use `pandas.DataFrame.plot` to automatically interface with matplotlib

# %%
def plot_pandas(df, title, xlabel, ylabel, loglog):
    plot = df.plot(kind="line", 
        marker='o', 
        title=title, 
        xlabel=xlabel,
        ylabel=ylabel, 
        grid=True,
        loglog=loglog
    )
    return plot

# %% [markdown]
# # Examples

# %%
ctks["mpi_random_strong"].dataframe.loc["main"][262144]

# %%
ctks.keys()

# %%
function_names = ("main", "comm", "comp_large")

# %% [markdown]
# # MPI STRONG SCALING TIME PLOTS

# %%
for name in function_names:
    for inputSize in [65536, 262144, 1048576, 4194304, 16777216, 67108864, 268435456]:
        masterDF = pd.DataFrame()
        for inputType in ctks.keys():
            if("strong" in inputType and "mpi" in inputType):
                tempDF = ctks[inputType].dataframe.loc[name][(inputSize, "Avg time/rank")]
                tempDF = tempDF.rename(inputType.split('_')[1])    
                masterDF = pd.concat([masterDF, tempDF], axis=1) 
              
        if(inputSize == 16777216 and name == "comp_large"):
            print(list(masterDF["perturbed"].values))
                

        plot_pandas(
            df=masterDF,
            title="SampleSort MPI, " + str(name) + ", Sorting " + str(inputSize) + " Values, Avg time/rank",
            xlabel="Num_Procs",
            ylabel="Time (seconds)",
            loglog=True
        )

# %% [markdown]
# # MPI WEAK SCALING TIME PLOTS

# %%
def count_nan(arr):
    count = 0
    for k in arr:
        if k >= 0:
            count += 1
    return count

for name in function_names:
    for inputType in ctks.keys():
        if "weak" in inputType and "mpi" in inputType:
            masterDF = pd.DataFrame()
            for inputSize in valsPerProcList: #[65536, 262144, 1048576, 4194304, 16777216, 67108864, 268435456]: #[262144.0, 524288.0, 1048576.0, 2097152.0, 4194304.0]: #[256.0, 512.0, 1024.0, 2048.0, 4096.0, 8192.0, 16384.0, 32768.0, 65536.0, 131072.0, 262144.0, 524288.0, 1048576.0, 2097152.0, 4194304.0, 8388608.0, 16777216.0, 33554432.0, 67108864.0, 134217728.0]: # for inputSize in [65536, 262144, 1048576, 4194304, 16777216, 67108864, 268435456]:
                tempDF = ctks[inputType].dataframe.loc[name][(inputSize, "Avg time/rank")]
                    
                if(count_nan(tempDF.values) > 4):
                    tempDF = tempDF.rename(inputSize)    
                    masterDF = pd.concat([masterDF, tempDF], axis=1) 
    
            masterDF = masterDF.apply(lambda x: x.fillna((x.shift() + x.shift(-1)) / 2))
            
            if(name == "comp_large" and "random" in inputType):
                print(masterDF[262144])
            
            plot_pandas(
                df=masterDF,
                title="SampleSort MPI, " + str(inputType.split("_")[1]) + " Input, " + str(name) + ", Avg time/rank",
                xlabel="Num Processors",
                ylabel="Time (seconds)",
                loglog=True
            )

# %% [markdown]
# # CUDA STRONG SCALING TIME PLOTS

# %%
for name in function_names:
    for inputSize in [32768, 65536, 131072, 262144, 524288, 1048576, 2097152]:
        masterDF = pd.DataFrame()
        for inputType in ctks.keys():
            if("strong" in inputType and "cuda" in inputType):
                tempDF = ctks[inputType].dataframe.loc[name][(inputSize, "Avg time/rank")]
                tempDF = tempDF.rename(inputType.split('_')[1])    
                masterDF = pd.concat([masterDF, tempDF], axis=1) 
                
        if(inputSize == 1048576 and name == "main"):
            print(list(masterDF["random"].values))

        plot_pandas(
            df=masterDF,
            title="SampleSort CUDA, " + str(name) + ", Sorting " + str(inputSize) + " Values, Avg time/rank",
            xlabel="Num_Blocks",
            ylabel="Time (seconds)",
            loglog=True
        )

# %% [markdown]
# # CUDA WEAK SCALING TIME PLOTS

# %%
def count_nan(arr):
    count = 0
    for k in arr:
        if k >= 0:
            count += 1
    return count

for name in function_names:
    for inputType in ctks.keys():
        if "weak" in inputType and "cuda" in inputType:
            masterDF = pd.DataFrame()
            for inputSize in valsPerBlockList: #[32768, 65536, 131072, 262144, 524288, 1048576, 2097152]: #[64, 128, 256, 512, 1024]: 
                tempDF = ctks[inputType].dataframe.loc[name][(inputSize, "Avg time/rank")]
                
                if(count_nan(tempDF.values) > 3):
                    tempDF = tempDF.rename(inputSize)    
                    masterDF = pd.concat([masterDF, tempDF], axis=1) 
    
            masterDF = masterDF.apply(lambda x: x.fillna((x.shift() + x.shift(-1)) / 2))

            if(name == "comp_large" and "random" in inputType):
                print(list(masterDF[2048].values))
            
            plot_pandas(
                df=masterDF,
                title="SampleSort CUDA, " + str(inputType.split("_")[1]) + " Input, " + str(name) + ", Avg time/rank",
                xlabel="Num_Blocks",
                ylabel="Time (seconds)",
                loglog=True
            )

# %% [markdown]
# ## Speedup

# %%
for inputType in ctks.keys():
    if("mpi" in inputType and "strong" in inputType):
        masterDF = pd.DataFrame()
        for inputSize in [65536, 262144, 1048576, 4194304, 16777216, 67108864, 268435456]:
            tempDF = ctks[inputType].dataframe.loc["comp_large"][(inputSize, "Avg time/rank")]
            tempDF = tempDF.rename(inputSize)    
            masterDF = pd.concat([masterDF, tempDF], axis=1) 
            

        for inputSize in masterDF.columns:
            masterDF[inputSize] = masterDF[inputSize][2] / masterDF[inputSize]
            
        if("random" in inputType):
            print(list(masterDF[67108864].values))

        plot_pandas(
            df=masterDF,
            title="SampleSort MPI, " + str(inputType.split("_")[1]) + " Input, comp_large, Speed-up",
            xlabel="Num Processors",
            ylabel="Speed-Up",
            loglog=True
        )

# %%
for inputType in ctks.keys():
    if("cuda" in inputType and "strong" in inputType):
        masterDF = pd.DataFrame()
        for inputSize in [32768, 65536, 131072, 262144, 524288, 1048576, 2097152]:
            tempDF = ctks[inputType].dataframe.loc["main"][(inputSize, "Avg time/rank")]
            tempDF = tempDF.rename(inputSize)    
            masterDF = pd.concat([masterDF, tempDF], axis=1) 

        for inputSize in masterDF.columns:
            masterDF[inputSize] = masterDF[inputSize][64] / masterDF[inputSize]
            
        if("random" in inputType):
            print(list(masterDF[1048576].values))

        plot_pandas(
            df=masterDF,
            title="SampleSort CUDA, " + str(inputType.split("_")[1]) + " Input, main, Speed-up",
            xlabel="Num Processors",
            ylabel="Speed-Up",
            loglog=True
        )
