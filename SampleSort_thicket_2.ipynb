# %% [markdown]
# # FINAL PROJECT THICKET

# %%
import sys
sys.path.append("/scratch/group/csce435-f23/python-3.8.17/lib/python3.8/site-packages")
sys.path.append("/scratch/group/csce435-f23/thicket")
from glob import glob

import matplotlib.pyplot as plt
plt.rcParams.update({'figure.max_open_warning': 0})
import pandas as pd

import thicket as th

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

print("done")
# Out:
# done

# %% [markdown]
# Read in all the files

# %% [markdown]
# # MPI Thicket Variables

# %%
mpi_random_tk = th.Thicket.from_caliperreader(glob("cali_files/sort3/*-sample.cali"))
mpi_perturbed_tk = th.Thicket.from_caliperreader(glob("cali_files/sort2/*-sample.cali"))
mpi_sorted_tk = th.Thicket.from_caliperreader(glob("cali_files/sort0/*sample.cali"))
mpi_reverse_tk = th.Thicket.from_caliperreader(glob("cali_files/sort1/*sample.cali"))

# %% [markdown]
# # CUDA Thicket Variables

# %%
# cuda_random_tk = th.Thicket.from_caliperreader(glob("cali_files/Bitonic_cali_files/*.cali"))
# cuda_perturbed_tk = th.Thicket.from_caliperreader(glob("cali_files/Bitonic_cali_files/*.cali"))
# cuda_sorted_tk = th.Thicket.from_caliperreader(glob("cali_files/Bitonic_cali_files/*.cali"))
# cuda_reverse_tk = th.Thicket.from_caliperreader(glob("cali_files/Bitonic_cali_files/*.cali"))

# %%
tks = {}

tks["mpi_sorted"] = mpi_sorted_tk
tks["mpi_reverse"] = mpi_reverse_tk
tks["mpi_random"] = mpi_random_tk
tks["mpi_perturbed"] = mpi_perturbed_tk

# tks["cuda_sorted"] = cuda_sorted_tk
# tks["cuda_reverse"] = cuda_reverse_tk
# tks["cuda_random"] = cuda_random_tk
# tks["cuda_perturbed"] = cuda_perturbed_tk

# %%
for i in tks.values():
    i.statsframe.dataframe["time"] = 1

# print(tks["cuda_random"].tree())

# %%
# Performance data
for inputType in tks.keys():
    if "mpi" in inputType:
        tks[inputType].metadata["values_per_proc"] = tks[inputType].metadata["InputSize"] // tks[inputType].metadata["num_procs"]
        
tks["mpi_random"].metadata
# Out:
#            cali.caliper.version  mpi.world.size  \
# profile
# 125094042            2.11.0-dev              64
# 136462064            2.11.0-dev            1024
# 224262369            2.11.0-dev               8
# 254330487            2.11.0-dev               8
# 267055606            2.11.0-dev              64
# 328894138            2.11.0-dev            1024
# 498735902            2.11.0-dev             128
# 512550339            2.11.0-dev              32
# 515405417            2.11.0-dev             128
# 602430384            2.11.0-dev              32
# 791874404            2.11.0-dev             512
# 1112895243           2.11.0-dev             256
# 1125817381           2.11.0-dev               2
# 1178857823           2.11.0-dev              32
# 1208028574           2.11.0-dev             256
# 1219508416           2.11.0-dev               2
# 1233138883           2.11.0-dev              32
# 1235336969           2.11.0-dev             512
# 1244749383           2.11.0-dev               8
# 1252107835           2.11.0-dev              16
# 1255156828           2.11.0-dev              64
# 1277230400           2.11.0-dev             256
# 1334413436           2.11.0-dev              32
# 1452988688           2.11.0-dev               4
# 1510749833           2.11.0-dev               4
# 1552742471           2.11.0-dev               8
# 1646947451           2.11.0-dev              64
# 1844985577           2.11.0-dev              32
# 1925583792           2.11.0-dev               8
# 1963726364           2.11.0-dev               4
# 1993344714           2.11.0-dev            1024
# 2071331326           2.11.0-dev             128
# 2202992537           2.11.0-dev             128
# 2239031269           2.11.0-dev            1024
# 2251050041           2.11.0-dev             256
# 2275966125           2.11.0-dev               4
# 2299812503           2.11.0-dev               8
# 2309438091           2.11.0-dev             512
# 2379841991           2.11.0-dev              16
# 2418087398           2.11.0-dev               2
# 2582505864           2.11.0-dev             512
# 2618268633           2.11.0-dev             256
# 2639201708           2.11.0-dev               4
# 2706012724           2.11.0-dev             256
# 2743877208           2.11.0-dev             256
# 2753158372           2.11.0-dev               4
# 2773050484           2.11.0-dev             512
# 2804866448           2.11.0-dev            1024
# 2940433378           2.11.0-dev              16
# 3077736110           2.11.0-dev               8
# 3078589478           2.11.0-dev              16
# 3098579292           2.11.0-dev            1024
# 3110591010           2.11.0-dev             128
# 3173294490           2.11.0-dev              64
# 3286481193           2.11.0-dev              64
# 3318007366           2.11.0-dev              16
# 3379292610           2.11.0-dev             512
# 3485875254           2.11.0-dev             128
# 3554194851           2.11.0-dev              32
# 3647364000           2.11.0-dev               2
# 3661393859           2.11.0-dev               2
# 3716488266           2.11.0-dev              16
# 3889166710           2.11.0-dev              16
# 3943886424           2.11.0-dev               2
# 3949347486           2.11.0-dev            1024
# 3982384336           2.11.0-dev             128
# 4063709671           2.11.0-dev               4
# 4252670885           2.11.0-dev              64
# 4254804346           2.11.0-dev               2
#
#                                                  spot.metrics  \
# profile
# 125094042   min#inclusive#sum#time.duration,max#inclusive#...
# 136462064   min#inclusive#sum#time.duration,max#inclusive#...
# 224262369   min#inclusive#sum#time.duration,max#inclusive#...
# 254330487   min#inclusive#sum#time.duration,max#inclusive#...
# 267055606   min#inclusive#sum#time.duration,max#inclusive#...
# 328894138   min#inclusive#sum#time.duration,max#inclusive#...
# 498735902   min#inclusive#sum#time.duration,max#inclusive#...
# 512550339   min#inclusive#sum#time.duration,max#inclusive#...
# 515405417   min#inclusive#sum#time.duration,max#inclusive#...
# 602430384   min#inclusive#sum#time.duration,max#inclusive#...
# 791874404   min#inclusive#sum#time.duration,max#inclusive#...
# 1112895243  min#inclusive#sum#time.duration,max#inclusive#...
# 1125817381  min#inclusive#sum#time.duration,max#inclusive#...
# 1178857823  min#inclusive#sum#time.duration,max#inclusive#...
# 1208028574  min#inclusive#sum#time.duration,max#inclusive#...
# 1219508416  min#inclusive#sum#time.duration,max#inclusive#...
# 1233138883  min#inclusive#sum#time.duration,max#inclusive#...
# 1235336969  min#inclusive#sum#time.duration,max#inclusive#...
# 1244749383  min#inclusive#sum#time.duration,max#inclusive#...
# 1252107835  min#inclusive#sum#time.duration,max#inclusive#...
# 1255156828  min#inclusive#sum#time.duration,max#inclusive#...
# 1277230400  min#inclusive#sum#time.duration,max#inclusive#...
# 1334413436  min#inclusive#sum#time.duration,max#inclusive#...
# 1452988688  min#inclusive#sum#time.duration,max#inclusive#...
# 1510749833  min#inclusive#sum#time.duration,max#inclusive#...
# 1552742471  min#inclusive#sum#time.duration,max#inclusive#...
# 1646947451  min#inclusive#sum#time.duration,max#inclusive#...
# 1844985577  min#inclusive#sum#time.duration,max#inclusive#...
# 1925583792  min#inclusive#sum#time.duration,max#inclusive#...
# 1963726364  min#inclusive#sum#time.duration,max#inclusive#...
# 1993344714  min#inclusive#sum#time.duration,max#inclusive#...
# 2071331326  min#inclusive#sum#time.duration,max#inclusive#...
# 2202992537  min#inclusive#sum#time.duration,max#inclusive#...
# 2239031269  min#inclusive#sum#time.duration,max#inclusive#...
# 2251050041  min#inclusive#sum#time.duration,max#inclusive#...
# 2275966125  min#inclusive#sum#time.duration,max#inclusive#...
# 2299812503  min#inclusive#sum#time.duration,max#inclusive#...
# 2309438091  min#inclusive#sum#time.duration,max#inclusive#...
# 2379841991  min#inclusive#sum#time.duration,max#inclusive#...
# 2418087398  min#inclusive#sum#time.duration,max#inclusive#...
# 2582505864  min#inclusive#sum#time.duration,max#inclusive#...
# 2618268633  min#inclusive#sum#time.duration,max#inclusive#...
# 2639201708  min#inclusive#sum#time.duration,max#inclusive#...
# 2706012724  min#inclusive#sum#time.duration,max#inclusive#...
# 2743877208  min#inclusive#sum#time.duration,max#inclusive#...
# 2753158372  min#inclusive#sum#time.duration,max#inclusive#...
# 2773050484  min#inclusive#sum#time.duration,max#inclusive#...
# 2804866448  min#inclusive#sum#time.duration,max#inclusive#...
# 2940433378  min#inclusive#sum#time.duration,max#inclusive#...
# 3077736110  min#inclusive#sum#time.duration,max#inclusive#...
# 3078589478  min#inclusive#sum#time.duration,max#inclusive#...
# 3098579292  min#inclusive#sum#time.duration,max#inclusive#...
# 3110591010  min#inclusive#sum#time.duration,max#inclusive#...
# 3173294490  min#inclusive#sum#time.duration,max#inclusive#...
# 3286481193  min#inclusive#sum#time.duration,max#inclusive#...
# 3318007366  min#inclusive#sum#time.duration,max#inclusive#...
# 3379292610  min#inclusive#sum#time.duration,max#inclusive#...
# 3485875254  min#inclusive#sum#time.duration,max#inclusive#...
# 3554194851  min#inclusive#sum#time.duration,max#inclusive#...
# 3647364000  min#inclusive#sum#time.duration,max#inclusive#...
# 3661393859  min#inclusive#sum#time.duration,max#inclusive#...
# 3716488266  min#inclusive#sum#time.duration,max#inclusive#...
# 3889166710  min#inclusive#sum#time.duration,max#inclusive#...
# 3943886424  min#inclusive#sum#time.duration,max#inclusive#...
# 3949347486  min#inclusive#sum#time.duration,max#inclusive#...
# 3982384336  min#inclusive#sum#time.duration,max#inclusive#...
# 4063709671  min#inclusive#sum#time.duration,max#inclusive#...
# 4252670885  min#inclusive#sum#time.duration,max#inclusive#...
# 4254804346  min#inclusive#sum#time.duration,max#inclusive#...
#
#            spot.timeseries.metrics  spot.format.version  \
# profile
# 125094042                                             2
# 136462064                                             2
# 224262369                                             2
# 254330487                                             2
# 267055606                                             2
# 328894138                                             2
# 498735902                                             2
# 512550339                                             2
# 515405417                                             2
# 602430384                                             2
# 791874404                                             2
# 1112895243                                            2
# 1125817381                                            2
# 1178857823                                            2
# 1208028574                                            2
# 1219508416                                            2
# 1233138883                                            2
# 1235336969                                            2
# 1244749383                                            2
# 1252107835                                            2
# 1255156828                                            2
# 1277230400                                            2
# 1334413436                                            2
# 1452988688                                            2
# 1510749833                                            2
# 1552742471                                            2
# 1646947451                                            2
# 1844985577                                            2
# 1925583792                                            2
# 1963726364                                            2
# 1993344714                                            2
# 2071331326                                            2
# 2202992537                                            2
# 2239031269                                            2
# 2251050041                                            2
# 2275966125                                            2
# 2299812503                                            2
# 2309438091                                            2
# 2379841991                                            2
# 2418087398                                            2
# 2582505864                                            2
# 2618268633                                            2
# 2639201708                                            2
# 2706012724                                            2
# 2743877208                                            2
# 2753158372                                            2
# 2773050484                                            2
# 2804866448                                            2
# 2940433378                                            2
# 3077736110                                            2
# 3078589478                                            2
# 3098579292                                            2
# 3110591010                                            2
# 3173294490                                            2
# 3286481193                                            2
# 3318007366                                            2
# 3379292610                                            2
# 3485875254                                            2
# 3554194851                                            2
# 3647364000                                            2
# 3661393859                                            2
# 3716488266                                            2
# 3889166710                                            2
# 3943886424                                            2
# 3949347486                                            2
# 3982384336                                            2
# 4063709671                                            2
# 4252670885                                            2
# 4254804346                                            2
#
#                         spot.options  spot.channels cali.channel  \
# profile
# 125094042   time.variance,node.order  regionprofile         spot
# 136462064   time.variance,node.order  regionprofile         spot
# 224262369   time.variance,node.order  regionprofile         spot
# 254330487   time.variance,node.order  regionprofile         spot
# 267055606   time.variance,node.order  regionprofile         spot
# 328894138   time.variance,node.order  regionprofile         spot
# 498735902   time.variance,node.order  regionprofile         spot
# 512550339   time.variance,node.order  regionprofile         spot
# 515405417   time.variance,node.order  regionprofile         spot
# 602430384   time.variance,node.order  regionprofile         spot
# 791874404   time.variance,node.order  regionprofile         spot
# 1112895243  time.variance,node.order  regionprofile         spot
# 1125817381  time.variance,node.order  regionprofile         spot
# 1178857823  time.variance,node.order  regionprofile         spot
# 1208028574  time.variance,node.order  regionprofile         spot
# 1219508416  time.variance,node.order  regionprofile         spot
# 1233138883  time.variance,node.order  regionprofile         spot
# 1235336969  time.variance,node.order  regionprofile         spot
# 1244749383  time.variance,node.order  regionprofile         spot
# 1252107835  time.variance,node.order  regionprofile         spot
# 1255156828  time.variance,node.order  regionprofile         spot
# 1277230400  time.variance,node.order  regionprofile         spot
# 1334413436  time.variance,node.order  regionprofile         spot
# 1452988688  time.variance,node.order  regionprofile         spot
# 1510749833  time.variance,node.order  regionprofile         spot
# 1552742471  time.variance,node.order  regionprofile         spot
# 1646947451  time.variance,node.order  regionprofile         spot
# 1844985577  time.variance,node.order  regionprofile         spot
# 1925583792  time.variance,node.order  regionprofile         spot
# 1963726364  time.variance,node.order  regionprofile         spot
# 1993344714  time.variance,node.order  regionprofile         spot
# 2071331326  time.variance,node.order  regionprofile         spot
# 2202992537  time.variance,node.order  regionprofile         spot
# 2239031269  time.variance,node.order  regionprofile         spot
# 2251050041  time.variance,node.order  regionprofile         spot
# 2275966125  time.variance,node.order  regionprofile         spot
# 2299812503  time.variance,node.order  regionprofile         spot
# 2309438091  time.variance,node.order  regionprofile         spot
# 2379841991  time.variance,node.order  regionprofile         spot
# 2418087398  time.variance,node.order  regionprofile         spot
# 2582505864  time.variance,node.order  regionprofile         spot
# 2618268633  time.variance,node.order  regionprofile         spot
# 2639201708  time.variance,node.order  regionprofile         spot
# 2706012724  time.variance,node.order  regionprofile         spot
# 2743877208  time.variance,node.order  regionprofile         spot
# 2753158372  time.variance,node.order  regionprofile         spot
# 2773050484  time.variance,node.order  regionprofile         spot
# 2804866448  time.variance,node.order  regionprofile         spot
# 2940433378  time.variance,node.order  regionprofile         spot
# 3077736110  time.variance,node.order  regionprofile         spot
# 3078589478  time.variance,node.order  regionprofile         spot
# 3098579292  time.variance,node.order  regionprofile         spot
# 3110591010  time.variance,node.order  regionprofile         spot
# 3173294490  time.variance,node.order  regionprofile         spot
# 3286481193  time.variance,node.order  regionprofile         spot
# 3318007366  time.variance,node.order  regionprofile         spot
# 3379292610  time.variance,node.order  regionprofile         spot
# 3485875254  time.variance,node.order  regionprofile         spot
# 3554194851  time.variance,node.order  regionprofile         spot
# 3647364000  time.variance,node.order  regionprofile         spot
# 3661393859  time.variance,node.order  regionprofile         spot
# 3716488266  time.variance,node.order  regionprofile         spot
# 3889166710  time.variance,node.order  regionprofile         spot
# 3943886424  time.variance,node.order  regionprofile         spot
# 3949347486  time.variance,node.order  regionprofile         spot
# 3982384336  time.variance,node.order  regionprofile         spot
# 4063709671  time.variance,node.order  regionprofile         spot
# 4252670885  time.variance,node.order  regionprofile         spot
# 4254804346  time.variance,node.order  regionprofile         spot
#
#            spot:node.order                   spot:output spot:time.variance  \
# profile
# 125094042             true     67108864-64-3-sample.cali               true
# 136462064             true    1048576-1024-3-sample.cali               true
# 224262369             true        262144-8-3-sample.cali               true
# 254330487             true       4194304-8-3-sample.cali               true
# 267055606             true        65536-64-3-sample.cali               true
# 328894138             true  268435456-1024-3-sample.cali               true
# 498735902             true     4194304-128-3-sample.cali               true
# 512550339             true      4194304-32-3-sample.cali               true
# 515405417             true    67108864-128-3-sample.cali               true
# 602430384             true        65536-32-3-sample.cali               true
# 791874404             true     4194304-512-3-sample.cali               true
# 1112895243            true    67108864-256-3-sample.cali               true
# 1125817381            true         65536-2-3-sample.cali               true
# 1178857823            true     16777216-32-3-sample.cali               true
# 1208028574            true    16777216-256-3-sample.cali               true
# 1219508416            true       1048576-2-3-sample.cali               true
# 1233138883            true     67108864-32-3-sample.cali               true
# 1235336969            true    16777216-512-3-sample.cali               true
# 1244749383            true      16777216-8-3-sample.cali               true
# 1252107835            true       262144-16-3-sample.cali               true
# 1255156828            true      1048576-64-3-sample.cali               true
# 1277230400            true     1048576-256-3-sample.cali               true
# 1334413436            true      1048576-32-3-sample.cali               true
# 1452988688            true      67108864-4-3-sample.cali               true
# 1510749833            true         65536-4-3-sample.cali               true
# 1552742471            true     268435456-8-3-sample.cali               true
# 1646947451            true      4194304-64-3-sample.cali               true
# 1844985577            true       262144-32-3-sample.cali               true
# 1925583792            true      67108864-8-3-sample.cali               true
# 1963726364            true        262144-4-3-sample.cali               true
# 1993344714            true      65536-1024-3-sample.cali               true
# 2071331326            true   268435456-128-3-sample.cali               true
# 2202992537            true      262144-128-3-sample.cali               true
# 2239031269            true     262144-1024-3-sample.cali               true
# 2251050041            true     4194304-256-3-sample.cali               true
# 2275966125            true       4194304-4-3-sample.cali               true
# 2299812503            true       1048576-8-3-sample.cali               true
# 2309438091            true      262144-512-3-sample.cali               true
# 2379841991            true     16777216-16-3-sample.cali               true
# 2418087398            true      16777216-2-3-sample.cali               true
# 2582505864            true   268435456-512-3-sample.cali               true
# 2618268633            true   268435456-256-3-sample.cali               true
# 2639201708            true      16777216-4-3-sample.cali               true
# 2706012724            true       65536-256-3-sample.cali               true
# 2743877208            true      262144-256-3-sample.cali               true
# 2753158372            true     268435456-4-3-sample.cali               true
# 2773050484            true       65536-512-3-sample.cali               true
# 2804866448            true    4194304-1024-3-sample.cali               true
# 2940433378            true     67108864-16-3-sample.cali               true
# 3077736110            true         65536-8-3-sample.cali               true
# 3078589478            true    268435456-16-3-sample.cali               true
# 3098579292            true   67108864-1024-3-sample.cali               true
# 3110591010            true    16777216-128-3-sample.cali               true
# 3173294490            true       262144-64-3-sample.cali               true
# 3286481193            true    268435456-64-3-sample.cali               true
# 3318007366            true      1048576-16-3-sample.cali               true
# 3379292610            true    67108864-512-3-sample.cali               true
# 3485875254            true     1048576-128-3-sample.cali               true
# 3554194851            true    268435456-32-3-sample.cali               true
# 3647364000            true     268435456-2-3-sample.cali               true
# 3661393859            true      67108864-2-3-sample.cali               true
# 3716488266            true      4194304-16-3-sample.cali               true
# 3889166710            true        65536-16-3-sample.cali               true
# 3943886424            true       4194304-2-3-sample.cali               true
# 3949347486            true   16777216-1024-3-sample.cali               true
# 3982384336            true       65536-128-3-sample.cali               true
# 4063709671            true       1048576-4-3-sample.cali               true
# 4252670885            true     16777216-64-3-sample.cali               true
# 4254804346            true        262144-2-3-sample.cali               true
#
#             launchdate                                          libraries  \
# profile
# 125094042   1700103914  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 136462064   1700102204  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 224262369   1700103819  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 254330487   1700103845  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 267055606   1700103792  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 328894138   1700102235  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 498735902   1700103848  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 512550339   1700103848  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 515405417   1700103914  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 602430384   1700103792  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 791874404   1700102206  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1112895243  1700103912  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1125817381  1700103780  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1178857823  1700103882  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1208028574  1700103894  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1219508416  1700103816  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1233138883  1700103912  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1235336969  1700102205  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1244749383  1700103873  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1252107835  1700103816  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1255156828  1700103816  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1277230400  1700103845  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1334413436  1700103816  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1452988688  1700103896  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1510749833  1700103780  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1552742471  1700103914  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1646947451  1700103848  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1844985577  1700103816  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1925583792  1700103896  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1963726364  1700103792  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 1993344714  1700102170  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2071331326  1700103934  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2202992537  1700103816  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2239031269  1700102182  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2251050041  1700103873  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2275966125  1700103844  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2299812503  1700103816  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2309438091  1700102182  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2379841991  1700103882  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2418087398  1700103873  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2582505864  1700102235  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2618268633  1700103932  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2639201708  1700103873  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2706012724  1700103792  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2743877208  1700103816  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2753158372  1700103914  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2773050484  1700102139  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2804866448  1700102205  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2940433378  1700103912  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3077736110  1700103780  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3078589478  1700103914  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3098579292  1700102235  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3110591010  1700103896  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3173294490  1700103816  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3286481193  1700103932  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3318007366  1700103816  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3379292610  1700102235  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3485875254  1700103845  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3554194851  1700103932  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3647364000  1700103914  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3661393859  1700103896  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3716488266  1700103845  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3889166710  1700103780  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3943886424  1700103844  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3949347486  1700102205  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 3982384336  1700103792  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 4063709671  1700103816  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 4252670885  1700103882  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 4254804346  1700103792  [/scratch/group/csce435-f23/Caliper/caliper/li...
#
#                                   cmdline cluster    Algorithm  \
# profile
# 125094042    [./sample_sort, 67108864, 3]       c  Sample Sort
# 136462064     [./sample_sort, 1048576, 3]       c  Sample Sort
# 224262369      [./sample_sort, 262144, 3]       c  Sample Sort
# 254330487     [./sample_sort, 4194304, 3]       c  Sample Sort
# 267055606       [./sample_sort, 65536, 3]       c  Sample Sort
# 328894138   [./sample_sort, 268435456, 3]       c  Sample Sort
# 498735902     [./sample_sort, 4194304, 3]       c  Sample Sort
# 512550339     [./sample_sort, 4194304, 3]       c  Sample Sort
# 515405417    [./sample_sort, 67108864, 3]       c  Sample Sort
# 602430384       [./sample_sort, 65536, 3]       c  Sample Sort
# 791874404     [./sample_sort, 4194304, 3]       c  Sample Sort
# 1112895243   [./sample_sort, 67108864, 3]       c  Sample Sort
# 1125817381      [./sample_sort, 65536, 3]       c  Sample Sort
# 1178857823   [./sample_sort, 16777216, 3]       c  Sample Sort
# 1208028574   [./sample_sort, 16777216, 3]       c  Sample Sort
# 1219508416    [./sample_sort, 1048576, 3]       c  Sample Sort
# 1233138883   [./sample_sort, 67108864, 3]       c  Sample Sort
# 1235336969   [./sample_sort, 16777216, 3]       c  Sample Sort
# 1244749383   [./sample_sort, 16777216, 3]       c  Sample Sort
# 1252107835     [./sample_sort, 262144, 3]       c  Sample Sort
# 1255156828    [./sample_sort, 1048576, 3]       c  Sample Sort
# 1277230400    [./sample_sort, 1048576, 3]       c  Sample Sort
# 1334413436    [./sample_sort, 1048576, 3]       c  Sample Sort
# 1452988688   [./sample_sort, 67108864, 3]       c  Sample Sort
# 1510749833      [./sample_sort, 65536, 3]       c  Sample Sort
# 1552742471  [./sample_sort, 268435456, 3]       c  Sample Sort
# 1646947451    [./sample_sort, 4194304, 3]       c  Sample Sort
# 1844985577     [./sample_sort, 262144, 3]       c  Sample Sort
# 1925583792   [./sample_sort, 67108864, 3]       c  Sample Sort
# 1963726364     [./sample_sort, 262144, 3]       c  Sample Sort
# 1993344714      [./sample_sort, 65536, 3]       c  Sample Sort
# 2071331326  [./sample_sort, 268435456, 3]       c  Sample Sort
# 2202992537     [./sample_sort, 262144, 3]       c  Sample Sort
# 2239031269     [./sample_sort, 262144, 3]       c  Sample Sort
# 2251050041    [./sample_sort, 4194304, 3]       c  Sample Sort
# 2275966125    [./sample_sort, 4194304, 3]       c  Sample Sort
# 2299812503    [./sample_sort, 1048576, 3]       c  Sample Sort
# 2309438091     [./sample_sort, 262144, 3]       c  Sample Sort
# 2379841991   [./sample_sort, 16777216, 3]       c  Sample Sort
# 2418087398   [./sample_sort, 16777216, 3]       c  Sample Sort
# 2582505864  [./sample_sort, 268435456, 3]       c  Sample Sort
# 2618268633  [./sample_sort, 268435456, 3]       c  Sample Sort
# 2639201708   [./sample_sort, 16777216, 3]       c  Sample Sort
# 2706012724      [./sample_sort, 65536, 3]       c  Sample Sort
# 2743877208     [./sample_sort, 262144, 3]       c  Sample Sort
# 2753158372  [./sample_sort, 268435456, 3]       c  Sample Sort
# 2773050484      [./sample_sort, 65536, 3]       c  Sample Sort
# 2804866448    [./sample_sort, 4194304, 3]       c  Sample Sort
# 2940433378   [./sample_sort, 67108864, 3]       c  Sample Sort
# 3077736110      [./sample_sort, 65536, 3]       c  Sample Sort
# 3078589478  [./sample_sort, 268435456, 3]       c  Sample Sort
# 3098579292   [./sample_sort, 67108864, 3]       c  Sample Sort
# 3110591010   [./sample_sort, 16777216, 3]       c  Sample Sort
# 3173294490     [./sample_sort, 262144, 3]       c  Sample Sort
# 3286481193  [./sample_sort, 268435456, 3]       c  Sample Sort
# 3318007366    [./sample_sort, 1048576, 3]       c  Sample Sort
# 3379292610   [./sample_sort, 67108864, 3]       c  Sample Sort
# 3485875254    [./sample_sort, 1048576, 3]       c  Sample Sort
# 3554194851  [./sample_sort, 268435456, 3]       c  Sample Sort
# 3647364000  [./sample_sort, 268435456, 3]       c  Sample Sort
# 3661393859   [./sample_sort, 67108864, 3]       c  Sample Sort
# 3716488266    [./sample_sort, 4194304, 3]       c  Sample Sort
# 3889166710      [./sample_sort, 65536, 3]       c  Sample Sort
# 3943886424    [./sample_sort, 4194304, 3]       c  Sample Sort
# 3949347486   [./sample_sort, 16777216, 3]       c  Sample Sort
# 3982384336      [./sample_sort, 65536, 3]       c  Sample Sort
# 4063709671    [./sample_sort, 1048576, 3]       c  Sample Sort
# 4252670885   [./sample_sort, 16777216, 3]       c  Sample Sort
# 4254804346     [./sample_sort, 262144, 3]       c  Sample Sort
#
#            ProgrammingModel Datatype  SizeOfDatatype  InputSize InputType  \
# profile
# 125094042               MPI      int               4   67108864    random
# 136462064               MPI      int               4    1048576    random
# 224262369               MPI      int               4     262144    random
# 254330487               MPI      int               4    4194304    random
# 267055606               MPI      int               4      65536    random
# 328894138               MPI      int               4  268435456    random
# 498735902               MPI      int               4    4194304    random
# 512550339               MPI      int               4    4194304    random
# 515405417               MPI      int               4   67108864    random
# 602430384               MPI      int               4      65536    random
# 791874404               MPI      int               4    4194304    random
# 1112895243              MPI      int               4   67108864    random
# 1125817381              MPI      int               4      65536    random
# 1178857823              MPI      int               4   16777216    random
# 1208028574              MPI      int               4   16777216    random
# 1219508416              MPI      int               4    1048576    random
# 1233138883              MPI      int               4   67108864    random
# 1235336969              MPI      int               4   16777216    random
# 1244749383              MPI      int               4   16777216    random
# 1252107835              MPI      int               4     262144    random
# 1255156828              MPI      int               4    1048576    random
# 1277230400              MPI      int               4    1048576    random
# 1334413436              MPI      int               4    1048576    random
# 1452988688              MPI      int               4   67108864    random
# 1510749833              MPI      int               4      65536    random
# 1552742471              MPI      int               4  268435456    random
# 1646947451              MPI      int               4    4194304    random
# 1844985577              MPI      int               4     262144    random
# 1925583792              MPI      int               4   67108864    random
# 1963726364              MPI      int               4     262144    random
# 1993344714              MPI      int               4      65536    random
# 2071331326              MPI      int               4  268435456    random
# 2202992537              MPI      int               4     262144    random
# 2239031269              MPI      int               4     262144    random
# 2251050041              MPI      int               4    4194304    random
# 2275966125              MPI      int               4    4194304    random
# 2299812503              MPI      int               4    1048576    random
# 2309438091              MPI      int               4     262144    random
# 2379841991              MPI      int               4   16777216    random
# 2418087398              MPI      int               4   16777216    random
# 2582505864              MPI      int               4  268435456    random
# 2618268633              MPI      int               4  268435456    random
# 2639201708              MPI      int               4   16777216    random
# 2706012724              MPI      int               4      65536    random
# 2743877208              MPI      int               4     262144    random
# 2753158372              MPI      int               4  268435456    random
# 2773050484              MPI      int               4      65536    random
# 2804866448              MPI      int               4    4194304    random
# 2940433378              MPI      int               4   67108864    random
# 3077736110              MPI      int               4      65536    random
# 3078589478              MPI      int               4  268435456    random
# 3098579292              MPI      int               4   67108864    random
# 3110591010              MPI      int               4   16777216    random
# 3173294490              MPI      int               4     262144    random
# 3286481193              MPI      int               4  268435456    random
# 3318007366              MPI      int               4    1048576    random
# 3379292610              MPI      int               4   67108864    random
# 3485875254              MPI      int               4    1048576    random
# 3554194851              MPI      int               4  268435456    random
# 3647364000              MPI      int               4  268435456    random
# 3661393859              MPI      int               4   67108864    random
# 3716488266              MPI      int               4    4194304    random
# 3889166710              MPI      int               4      65536    random
# 3943886424              MPI      int               4    4194304    random
# 3949347486              MPI      int               4   16777216    random
# 3982384336              MPI      int               4      65536    random
# 4063709671              MPI      int               4    1048576    random
# 4252670885              MPI      int               4   16777216    random
# 4254804346              MPI      int               4     262144    random
#
#             num_procs  num_threads  group_num implementation_source  \
# profile
# 125094042          64            0         14           Handwritten
# 136462064        1024            0         14           Handwritten
# 224262369           8            0         14           Handwritten
# 254330487           8            0         14           Handwritten
# 267055606          64            0         14           Handwritten
# 328894138        1024            0         14           Handwritten
# 498735902         128            0         14           Handwritten
# 512550339          32            0         14           Handwritten
# 515405417         128            0         14           Handwritten
# 602430384          32            0         14           Handwritten
# 791874404         512            0         14           Handwritten
# 1112895243        256            0         14           Handwritten
# 1125817381          2            0         14           Handwritten
# 1178857823         32            0         14           Handwritten
# 1208028574        256            0         14           Handwritten
# 1219508416          2            0         14           Handwritten
# 1233138883         32            0         14           Handwritten
# 1235336969        512            0         14           Handwritten
# 1244749383          8            0         14           Handwritten
# 1252107835         16            0         14           Handwritten
# 1255156828         64            0         14           Handwritten
# 1277230400        256            0         14           Handwritten
# 1334413436         32            0         14           Handwritten
# 1452988688          4            0         14           Handwritten
# 1510749833          4            0         14           Handwritten
# 1552742471          8            0         14           Handwritten
# 1646947451         64            0         14           Handwritten
# 1844985577         32            0         14           Handwritten
# 1925583792          8            0         14           Handwritten
# 1963726364          4            0         14           Handwritten
# 1993344714       1024            0         14           Handwritten
# 2071331326        128            0         14           Handwritten
# 2202992537        128            0         14           Handwritten
# 2239031269       1024            0         14           Handwritten
# 2251050041        256            0         14           Handwritten
# 2275966125          4            0         14           Handwritten
# 2299812503          8            0         14           Handwritten
# 2309438091        512            0         14           Handwritten
# 2379841991         16            0         14           Handwritten
# 2418087398          2            0         14           Handwritten
# 2582505864        512            0         14           Handwritten
# 2618268633        256            0         14           Handwritten
# 2639201708          4            0         14           Handwritten
# 2706012724        256            0         14           Handwritten
# 2743877208        256            0         14           Handwritten
# 2753158372          4            0         14           Handwritten
# 2773050484        512            0         14           Handwritten
# 2804866448       1024            0         14           Handwritten
# 2940433378         16            0         14           Handwritten
# 3077736110          8            0         14           Handwritten
# 3078589478         16            0         14           Handwritten
# 3098579292       1024            0         14           Handwritten
# 3110591010        128            0         14           Handwritten
# 3173294490         64            0         14           Handwritten
# 3286481193         64            0         14           Handwritten
# 3318007366         16            0         14           Handwritten
# 3379292610        512            0         14           Handwritten
# 3485875254        128            0         14           Handwritten
# 3554194851         32            0         14           Handwritten
# 3647364000          2            0         14           Handwritten
# 3661393859          2            0         14           Handwritten
# 3716488266         16            0         14           Handwritten
# 3889166710         16            0         14           Handwritten
# 3943886424          2            0         14           Handwritten
# 3949347486       1024            0         14           Handwritten
# 3982384336        128            0         14           Handwritten
# 4063709671          4            0         14           Handwritten
# 4252670885         64            0         14           Handwritten
# 4254804346          2            0         14           Handwritten
#
#            correctness  values_per_proc
# profile
# 125094042      success          1048576
# 136462064      success             1024
# 224262369      success            32768
# 254330487      success           524288
# 267055606      success             1024
# 328894138      success           262144
# 498735902      success            32768
# 512550339      success           131072
# 515405417      success           524288
# 602430384      success             2048
# 791874404      success             8192
# 1112895243     success           262144
# 1125817381     success            32768
# 1178857823     success           524288
# 1208028574     success            65536
# 1219508416     success           524288
# 1233138883     success          2097152
# 1235336969     success            32768
# 1244749383     success          2097152
# 1252107835     success            16384
# 1255156828     success            16384
# 1277230400     success             4096
# 1334413436     success            32768
# 1452988688     success         16777216
# 1510749833     success            16384
# 1552742471     success         33554432
# 1646947451     success            65536
# 1844985577     success             8192
# 1925583792     success          8388608
# 1963726364     success            65536
# 1993344714     success               64
# 2071331326     success          2097152
# 2202992537     success             2048
# 2239031269     success              256
# 2251050041     success            16384
# 2275966125     success          1048576
# 2299812503     success           131072
# 2309438091     success              512
# 2379841991     success          1048576
# 2418087398     success          8388608
# 2582505864     success           524288
# 2618268633     success          1048576
# 2639201708     success          4194304
# 2706012724     success              256
# 2743877208     success             1024
# 2753158372     success         67108864
# 2773050484     success              128
# 2804866448     success             4096
# 2940433378     success          4194304
# 3077736110     success             8192
# 3078589478     success         16777216
# 3098579292     success            65536
# 3110591010     success           131072
# 3173294490     success             4096
# 3286481193     success          4194304
# 3318007366     success            65536
# 3379292610     success           131072
# 3485875254     success             8192
# 3554194851     success          8388608
# 3647364000     success        134217728
# 3661393859     success         33554432
# 3716488266     success           262144
# 3889166710     success             4096
# 3943886424     success          2097152
# 3949347486     success            16384
# 3982384336     success              512
# 4063709671     success           262144
# 4252670885     success           262144
# 4254804346     success           131072

# %%
tks.keys()
# Out:
# dict_keys(['mpi_sorted', 'mpi_reverse', 'mpi_random', 'mpi_perturbed'])

# %%
gbs = {}

for i in tks.keys():
    if "mpi" in i:
        gbs[i + "_strong"] = tks[i].groupby("InputSize")
        gbs[i + "_weak"] = tks[i].groupby("values_per_proc")
    else:
        gbs[i + "_strong"] = tks[i].groupby("InputSize")
        gbs[i + "_weak"] = tks[i].groupby("num_blocks")
# Out:
# 8  thickets created...
# {65536: <thicket.thicket.Thicket object at 0x2b58b2db1520>, 262144: <thicket.thicket.Thicket object at 0x2b58b2cf8a90>, 1048576: <thicket.thicket.Thicket object at 0x2b58b2ed79d0>, 4194304: <thicket.thicket.Thicket object at 0x2b58b2b760a0>, 16777216: <thicket.thicket.Thicket object at 0x2b58b2dc55b0>, 67108864: <thicket.thicket.Thicket object at 0x2b58b27726a0>, 167772216: <thicket.thicket.Thicket object at 0x2b58b2dcc640>, 268435456: <thicket.thicket.Thicket object at 0x2b58b272ba30>}
# 23  thickets created...
# {64: <thicket.thicket.Thicket object at 0x2b58b26b7b20>, 128: <thicket.thicket.Thicket object at 0x2b58b2b60220>, 256: <thicket.thicket.Thicket object at 0x2b58b2b60160>, 512: <thicket.thicket.Thicket object at 0x2b58b2d00d60>, 1024: <thicket.thicket.Thicket object at 0x2b58b29282b0>, 2048: <thicket.thicket.Thicket object at 0x2b58b263caf0>, 4096: <thicket.thicket.Thicket object at 0x2b58b2ddd280>, 8192: <thicket.thicket.Thicket object at 0x2b58b2bbaf10>, 16384: <thicket.thicket.Thicket object at 0x2b58b2c805b0>, 32768: <thicket.thicket.Thicket object at 0x2b58b2edf5e0>, 65536: <thicket.thicket.Thicket object at 0x2b58b27b0040>, 131072: <thicket.thicket.Thicket object at 0x2b58b2b710d0>, 262144: <thicket.thicket.Thicket object at 0x2b58b2eb2ac0>, 524288: <thicket.thicket.Thicket object at 0x2b58b2e754f0>, 1048576: <thicket.thicket.Thicket object at 0x2b58b2e6b490>, 1310720: <thicket.thicket.Thicket object at 0x2b58b2ed2c10>, 2097152: <thicket.thicket.Thicket object at 0x2b58b2ed26d0>, 4194304: <thicket.thicket.Thicket object at 0x2b58b2ef6280>, 8388608: <thicket.thicket.Thicket object at 0x2b58b2e90640>, 16777216: <thicket.thicket.Thicket object at 0x2b58b2c9f0d0>, 33554432: <thicket.thicket.Thicket object at 0x2b58b2ea2190>, 67108864: <thicket.thicket.Thicket object at 0x2b58b2e780a0>, 134217728: <thicket.thicket.Thicket object at 0x2b58b29a1e80>}
# 8  thickets created...
# {65536: <thicket.thicket.Thicket object at 0x2b58b2b124f0>, 262144: <thicket.thicket.Thicket object at 0x2b58b2b6b7c0>, 1048576: <thicket.thicket.Thicket object at 0x2b58b2d8cc70>, 4194304: <thicket.thicket.Thicket object at 0x2b58b2d3a7f0>, 16777216: <thicket.thicket.Thicket object at 0x2b58b2d3ca90>, 67108864: <thicket.thicket.Thicket object at 0x2b58b2d80760>, 167772216: <thicket.thicket.Thicket object at 0x2b58b2d614c0>, 268435456: <thicket.thicket.Thicket object at 0x2b58b2d66190>}
# 23  thickets created...
# {64: <thicket.thicket.Thicket object at 0x2b58b27c5f10>, 128: <thicket.thicket.Thicket object at 0x2b58b2ab9cd0>, 256: <thicket.thicket.Thicket object at 0x2b58b2764cd0>, 512: <thicket.thicket.Thicket object at 0x2b58b2d15700>, 1024: <thicket.thicket.Thicket object at 0x2b58b2d12a30>, 2048: <thicket.thicket.Thicket object at 0x2b58b28fc460>, 4096: <thicket.thicket.Thicket object at 0x2b58b2a5b9d0>, 8192: <thicket.thicket.Thicket object at 0x2b58b28dde20>, 16384: <thicket.thicket.Thicket object at 0x2b58b2abb1c0>, 32768: <thicket.thicket.Thicket object at 0x2b58b2610f70>, 65536: <thicket.thicket.Thicket object at 0x2b58b2c48ac0>, 131072: <thicket.thicket.Thicket object at 0x2b58b26cae20>, 262144: <thicket.thicket.Thicket object at 0x2b58b2a254c0>, 524288: <thicket.thicket.Thicket object at 0x2b58b26fa8e0>, 1048576: <thicket.thicket.Thicket object at 0x2b58b273fe50>, 1310720: <thicket.thicket.Thicket object at 0x2b58b2750b80>, 2097152: <thicket.thicket.Thicket object at 0x2b58b27f0f40>, 4194304: <thicket.thicket.Thicket object at 0x2b58b27f0130>, 8388608: <thicket.thicket.Thicket object at 0x2b58b29a7310>, 16777216: <thicket.thicket.Thicket object at 0x2b58b2bd4ee0>, 33554432: <thicket.thicket.Thicket object at 0x2b58b2622cd0>, 67108864: <thicket.thicket.Thicket object at 0x2b58b2be62e0>, 134217728: <thicket.thicket.Thicket object at 0x2b58b276dfd0>}
# 7  thickets created...
# {65536: <thicket.thicket.Thicket object at 0x2b58b2810460>, 262144: <thicket.thicket.Thicket object at 0x2b58b2c9c190>, 1048576: <thicket.thicket.Thicket object at 0x2b58b28b1df0>, 4194304: <thicket.thicket.Thicket object at 0x2b58b2757fa0>, 16777216: <thicket.thicket.Thicket object at 0x2b58b25a9d30>, 67108864: <thicket.thicket.Thicket object at 0x2b58b295c340>, 268435456: <thicket.thicket.Thicket object at 0x2b58b2c5d340>}
# 22  thickets created...
# {64: <thicket.thicket.Thicket object at 0x2b58b2d4fee0>, 128: <thicket.thicket.Thicket object at 0x2b58b2bb2970>, 256: <thicket.thicket.Thicket object at 0x2b58b2b02850>, 512: <thicket.thicket.Thicket object at 0x2b58b2a38f10>, 1024: <thicket.thicket.Thicket object at 0x2b58b267b7f0>, 2048: <thicket.thicket.Thicket object at 0x2b58b2986310>, 4096: <thicket.thicket.Thicket object at 0x2b58b2a41850>, 8192: <thicket.thicket.Thicket object at 0x2b58b29bc670>, 16384: <thicket.thicket.Thicket object at 0x2b58b2b36070>, 32768: <thicket.thicket.Thicket object at 0x2b58b2b4ca60>, 65536: <thicket.thicket.Thicket object at 0x2b58b298c3d0>, 131072: <thicket.thicket.Thicket object at 0x2b58b2a67250>, 262144: <thicket.thicket.Thicket object at 0x2b58b2d0c760>, 524288: <thicket.thicket.Thicket object at 0x2b58b2a9e580>, 1048576: <thicket.thicket.Thicket object at 0x2b58b2b780a0>, 2097152: <thicket.thicket.Thicket object at 0x2b58b2b89490>, 4194304: <thicket.thicket.Thicket object at 0x2b58b29565e0>, 8388608: <thicket.thicket.Thicket object at 0x2b58b2bdba30>, 16777216: <thicket.thicket.Thicket object at 0x2b58b2758400>, 33554432: <thicket.thicket.Thicket object at 0x2b58b2ea33a0>, 67108864: <thicket.thicket.Thicket object at 0x2b58b2eba670>, 134217728: <thicket.thicket.Thicket object at 0x2b58b2e80f40>}
# 8  thickets created...
# {65536: <thicket.thicket.Thicket object at 0x2b58b2f5af40>, 262144: <thicket.thicket.Thicket object at 0x2b58b2f6ccd0>, 1048576: <thicket.thicket.Thicket object at 0x2b58b2f73a30>, 4194304: <thicket.thicket.Thicket object at 0x2b58b2f60400>, 16777216: <thicket.thicket.Thicket object at 0x2b58b2f90610>, 67108864: <thicket.thicket.Thicket object at 0x2b58b2f97ac0>, 167772216: <thicket.thicket.Thicket object at 0x2b58b2f88970>, 268435456: <thicket.thicket.Thicket object at 0x2b58b2f92490>}
# 23  thickets created...
# {64: <thicket.thicket.Thicket object at 0x2b58b2fb8610>, 128: <thicket.thicket.Thicket object at 0x2b58b2fbf4c0>, 256: <thicket.thicket.Thicket object at 0x2b58b2ff3310>, 512: <thicket.thicket.Thicket object at 0x2b58b2ff9d30>, 1024: <thicket.thicket.Thicket object at 0x2b58b2fc4730>, 2048: <thicket.thicket.Thicket object at 0x2b58b2fcb3d0>, 4096: <thicket.thicket.Thicket object at 0x2b58b2fd6070>, 8192: <thicket.thicket.Thicket object at 0x2b58b3007430>, 16384: <thicket.thicket.Thicket object at 0x2b58b300dcd0>, 32768: <thicket.thicket.Thicket object at 0x2b58b30196d0>, 65536: <thicket.thicket.Thicket object at 0x2b58b3025580>, 131072: <thicket.thicket.Thicket object at 0x2b58b30320a0>, 262144: <thicket.thicket.Thicket object at 0x2b58b30322e0>, 524288: <thicket.thicket.Thicket object at 0x2b58b3648d90>, 1048576: <thicket.thicket.Thicket object at 0x2b58b36566d0>, 1310720: <thicket.thicket.Thicket object at 0x2b58b3662340>, 2097152: <thicket.thicket.Thicket object at 0x2b58b366f1f0>, 4194304: <thicket.thicket.Thicket object at 0x2b58b3662b80>, 8388608: <thicket.thicket.Thicket object at 0x2b58b3682c40>, 16777216: <thicket.thicket.Thicket object at 0x2b58b3691820>, 33554432: <thicket.thicket.Thicket object at 0x2b58b369d340>, 67108864: <thicket.thicket.Thicket object at 0x2b58b36a7310>, 134217728: <thicket.thicket.Thicket object at 0x2b58b36afc70>}

# %% [markdown]
# Compose these 3 groups column-wise to get a holistic view of the data

# %%
print(gbs.keys())
# Out:
# dict_keys(['mpi_sorted_strong', 'mpi_sorted_weak', 'mpi_reverse_strong', 'mpi_reverse_weak', 'mpi_random_strong', 'mpi_random_weak', 'mpi_perturbed_strong', 'mpi_perturbed_weak'])

# %%
ctks = {}

for i in gbs.keys():
#     if "strong" in i:
    if "mpi" in i:
        ctks[i] = th.Thicket.concat_thickets(
            thickets=list(gbs[i].values()),
            headers=list(gbs[i].keys()),
            axis="columns",
            metadata_key="num_procs"
        )
    else:
        ctks[i] = th.Thicket.concat_thickets(
            thickets=list(gbs[i].values()),
            headers=list(gbs[i].keys()),
            axis="columns",
            metadata_key="num_threads"
        )

# %%
valsPerProcList = ctks["mpi_random_weak"].dataframe.columns.get_level_values(0).unique().drop("name")

# %%
#valsPerBlockList = ctks["cuda_random_weak"].dataframe.columns.get_level_values(0).unique().drop("name")

# %% [markdown]
# Perform pandas operations to get the table in a desirable format for plotting

# %%
for i in ctks.keys():
    if "cuda" in i:
        if "strong" in i:
            for inputSize in [32768, 65536, 131072, 262144, 524288, 1048576, 2097152]:
                ctks[i].dataframe = ctks[i].dataframe.drop([(inputSize, "nid"), (inputSize, "spot.channel")], axis=1)
            ctks[i].dataframe = ctks[i].dataframe.reset_index().drop([("node", "")], axis=1)
            ctks[i].dataframe = ctks[i].dataframe.rename({("name", ""): "name", ("num_threads", ""): "num_threads"}).set_index(["name", "num_threads"])

        else:
            for valPerBlock in valsPerBlockList: #[32768, 65536, 131072, 262144, 524288, 1048576, 2097152]:
                ctks[i].dataframe = ctks[i].dataframe.drop([(valPerBlock, "nid"), (valPerBlock, "spot.channel")], axis=1)
            ctks[i].dataframe = ctks[i].dataframe.reset_index().drop([("node", "")], axis=1)
            ctks[i].dataframe = ctks[i].dataframe.rename({("name", ""): "name", ("num_threads", ""): "num_threads"}).set_index(["name", "num_threads"])

    else:
        if "strong" in i:
            for inputSize in [65536, 262144, 1048576, 4194304, 16777216, 67108864, 268435456]:
                ctks[i].dataframe = ctks[i].dataframe.drop([(inputSize, "nid"), (inputSize, "spot.channel")], axis=1)

            ctks[i].dataframe = ctks[i].dataframe.reset_index().drop([("node", "")], axis=1)
            ctks[i].dataframe = ctks[i].dataframe.rename({("name", ""): "name", ("num_procs", ""): "num_procs"}).set_index(["name", "num_procs"])
            
        else: 
            for valPerProc in valsPerProcList: #[65536, 262144, 1048576, 4194304, 16777216, 67108864, 268435456]:
                ctks[i].dataframe = ctks[i].dataframe.drop([(valPerProc, "nid"), (valPerProc, "spot.channel")], axis=1)

            ctks[i].dataframe = ctks[i].dataframe.reset_index().drop([("node", "")], axis=1)
            ctks[i].dataframe = ctks[i].dataframe.rename({("name", ""): "name", ("num_procs", ""): "num_procs"}).set_index(["name", "num_procs"])

# %%
#ctks["cuda_sorted_weak"].dataframe

# %% [markdown]
# # Plotting

# %% [markdown]
# ### Option 1
# Use `pandas.DataFrame.plot` to automatically interface with matplotlib

# %%
def plot_pandas(df, title, xlabel, ylabel, loglog):
    plot = df.plot(kind="line", 
        marker='o', 
        title=title, 
        xlabel=xlabel,
        ylabel=ylabel,          
        grid=True,
        loglog=loglog
    )
    return plot

# %% [markdown]
# # Examples

# %%
ctks["mpi_random_strong"].dataframe.loc["main"][262144]
# Out:
#            Min time/rank  Max time/rank  Avg time/rank     Total time  \
# num_procs
# 2               0.105585       0.105678       0.105632       0.211263
# 4               0.040534       0.054986       0.047853       0.191411
# 8               0.032633       0.042592       0.037985       0.303883
# 16              0.026174       0.031347       0.027944       0.447105
# 32              0.032825       0.100838       0.085817       2.746137
# 64              0.473576       0.648794       0.573625      36.711991
# 128             1.215248       1.427947       1.317366     168.622905
# 256             4.723179       5.030524       4.889010    1251.586446
# 512            33.881455      34.387348      34.120917   17469.909291
# 1024          227.233960     228.154917     227.681029  233145.373806
#
#            Variance time/rank
# num_procs
# 2                    0.000000
# 4                    0.000051
# 8                    0.000013
# 16                   0.000002
# 32                   0.000422
# 64                   0.003508
# 128                  0.002139
# 256                  0.003466
# 512                  0.009641
# 1024                 0.042410

# %%
ctks.keys()
# Out:
# dict_keys(['mpi_sorted_strong', 'mpi_sorted_weak', 'mpi_reverse_strong', 'mpi_reverse_weak', 'mpi_random_strong', 'mpi_random_weak', 'mpi_perturbed_strong', 'mpi_perturbed_weak'])

# %%
function_names = ("main", "comm", "comp_large")

# %% [markdown]
# # MPI STRONG SCALING TIME PLOTS

# %%
for name in function_names:
    for inputSize in [65536, 262144, 1048576, 4194304, 16777216, 67108864, 268435456]:
        masterDF = pd.DataFrame()
        for inputType in ctks.keys():
            if("strong" in inputType and "mpi" in inputType):
                tempDF = ctks[inputType].dataframe.loc[name][(inputSize, "Avg time/rank")]
                tempDF = tempDF.rename(inputType.split('_')[1])    
                masterDF = pd.concat([masterDF, tempDF], axis=1) 
              
        if(inputSize == 16777216 and name == "comp_large"):
            print(list(masterDF["perturbed"].values))
                

        plot_pandas(
            df=masterDF,
            title="SampleSort MPI, " + str(name) + ", Sorting " + str(inputSize) + " Values, Avg time/rank",
            xlabel="Num_Procs",
            ylabel="Time (seconds)",
            loglog=True
        )
# Out:
# [4.921768, 2.213658, 2.060183, 2.052196, 2.075947, 2.158413, nan, 0.393539, 0.381564, 0.526793]

# %% [markdown]
# # MPI WEAK SCALING TIME PLOTS

# %%
def count_nan(arr):
    count = 0
    for k in arr:
        if k >= 0:
            count += 1
    return count

for name in function_names:
    for inputType in ctks.keys():
        if "weak" in inputType and "mpi" in inputType:
            masterDF = pd.DataFrame()
            for inputSize in valsPerProcList: #[65536, 262144, 1048576, 4194304, 16777216, 67108864, 268435456]: #[262144.0, 524288.0, 1048576.0, 2097152.0, 4194304.0]: #[256.0, 512.0, 1024.0, 2048.0, 4096.0, 8192.0, 16384.0, 32768.0, 65536.0, 131072.0, 262144.0, 524288.0, 1048576.0, 2097152.0, 4194304.0, 8388608.0, 16777216.0, 33554432.0, 67108864.0, 134217728.0]: # for inputSize in [65536, 262144, 1048576, 4194304, 16777216, 67108864, 268435456]:
                tempDF = ctks[inputType].dataframe.loc[name][(inputSize, "Avg time/rank")]
                    
                if(count_nan(tempDF.values) > 4):
                    tempDF = tempDF.rename(inputSize)    
                    masterDF = pd.concat([masterDF, tempDF], axis=1) 
    
            masterDF = masterDF.apply(lambda x: x.fillna((x.shift() + x.shift(-1)) / 2))
            
            if(name == "comp_large" and "random" in inputType):
                print(masterDF[262144])
            
            plot_pandas(
                df=masterDF,
                title="SampleSort MPI, " + str(inputType.split("_")[1]) + " Input, " + str(name) + ", Avg time/rank",
                xlabel="Num Processors",
                ylabel="Time (seconds)",
                
                loglog=True
            )
# Out:
# 2            NaN
# 4       0.108671
# 8       0.111235
# 16      0.113798
# 32      0.153443
# 64      0.193087
# 128     0.616341
# 256     1.039596
# 512     5.419979
# 1024    9.800361
# Name: 262144, dtype: float64

# %% [markdown]
# # CUDA STRONG SCALING TIME PLOTS

# %%
for name in function_names:
    for inputSize in [32768, 65536, 131072, 262144, 524288, 1048576, 2097152]:
        masterDF = pd.DataFrame()
        for inputType in ctks.keys():
            if("strong" in inputType and "cuda" in inputType):
                tempDF = ctks[inputType].dataframe.loc[name][(inputSize, "Avg time/rank")]
                tempDF = tempDF.rename(inputType.split('_')[1])    
                masterDF = pd.concat([masterDF, tempDF], axis=1) 
                
        if(inputSize == 1048576 and name == "main"):
            print(list(masterDF["random"].values))

        plot_pandas(
            df=masterDF,
            title="SampleSort CUDA, " + str(name) + ", Sorting " + str(inputSize) + " Values, Avg time/rank",
            xlabel="Num_Blocks",
            ylabel="Time (seconds)",
            loglog=True
        )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-dc837eb8c972> in <module>
#      11             print(list(masterDF["random"].values))
#      12
# ---> 13         plot_pandas(
#      14             df=masterDF,
#      15             title="SampleSort CUDA, " + str(name) + ", Sorting " + str(inputSize) + " Values, Avg time/rank",
#
# <ipython-input-15-ed170e39f28d> in plot_pandas(df, title, xlabel, ylabel, loglog)
#       1 def plot_pandas(df, title, xlabel, ylabel, loglog):
# ----> 2     plot = df.plot(kind="line",
#       3         marker='o',
#       4         title=title,
#       5         xlabel=xlabel,
#
# /scratch/group/csce435-f23/python-3.8.17/lib/python3.8/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     973                     data.columns = label_name
#     974
# --> 975         return plot_backend.plot(data, kind=kind, **kwargs)
#     976
#     977     __call__.__doc__ = __doc__
#
# /scratch/group/csce435-f23/python-3.8.17/lib/python3.8/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
#      73     return plot_obj.result
#
# /scratch/group/csce435-f23/python-3.8.17/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py in generate(self)
#     444     def generate(self) -> None:
#     445         self._args_adjust()
# --> 446         self._compute_plot_data()
#     447         self._setup_subplots()
#     448         self._make_plot()
#
# /scratch/group/csce435-f23/python-3.8.17/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py in _compute_plot_data(self)
#     630         # no non-numeric frames or series allowed
#     631         if is_empty:
# --> 632             raise TypeError("no numeric data to plot")
#     633
#     634         self.data = numeric_data.apply(self._convert_to_ndarray)
#
# TypeError: no numeric data to plot

# %% [markdown]
# # CUDA WEAK SCALING TIME PLOTS

# %%
def count_nan(arr):
    count = 0
    for k in arr:
        if k >= 0:
            count += 1
    return count

for name in function_names:
    for inputType in ctks.keys():
        if "weak" in inputType and "cuda" in inputType:
            masterDF = pd.DataFrame()
            for inputSize in valsPerBlockList: #[32768, 65536, 131072, 262144, 524288, 1048576, 2097152]: #[64, 128, 256, 512, 1024]: 
                tempDF = ctks[inputType].dataframe.loc[name][(inputSize, "Avg time/rank")]
                
                if(count_nan(tempDF.values) > 3):
                    tempDF = tempDF.rename(inputSize)    
                    masterDF = pd.concat([masterDF, tempDF], axis=1) 
    
            masterDF = masterDF.apply(lambda x: x.fillna((x.shift() + x.shift(-1)) / 2))

            if(name == "comp_large" and "random" in inputType):
                print(list(masterDF[2048].values))
            
            plot_pandas(
                df=masterDF,
                title="SampleSort CUDA, " + str(inputType.split("_")[1]) + " Input, " + str(name) + ", Avg time/rank",
                xlabel="Num_Blocks",
                ylabel="Time (seconds)",
                loglog=True
            )

# %% [markdown]
# ## Speedup

# %%
for inputType in ctks.keys():
    if("mpi" in inputType and "strong" in inputType):
        masterDF = pd.DataFrame()
        
        for inputSize in [65536, 262144, 1048576, 4194304, 16777216, 67108864, 268435456]:
            tempDF = ctks[inputType].dataframe.loc["comp_large"][(inputSize, "Avg time/rank")]
            tempDF = tempDF.rename(inputSize)    
            masterDF = pd.concat([masterDF, tempDF], axis=1) 
        
        print(masterDF)

        for inputSize in masterDF.columns:
            masterDF[inputSize] = masterDF[inputSize][2] / masterDF[inputSize]
            
        if("random" in inputType):
            print(list(masterDF[67108864].values))

        plot_pandas(
            df=masterDF,
            title="SampleSort MPI, " + str(inputType.split("_")[1]) + " Input, comp_large, Speed-up",
            xlabel="Num Processors",
            ylabel="Speed-Up",
            loglog=True
        )

# %%
for inputType in ctks.keys():
    if("cuda" in inputType and "strong" in inputType):
        masterDF = pd.DataFrame()
        for inputSize in [32768, 65536, 131072, 262144, 524288, 1048576, 2097152]:
            tempDF = ctks[inputType].dataframe.loc["main"][(inputSize, "Avg time/rank")]
            tempDF = tempDF.rename(inputSize)    
            masterDF = pd.concat([masterDF, tempDF], axis=1) 

        for inputSize in masterDF.columns:
            masterDF[inputSize] = masterDF[inputSize][64] / masterDF[inputSize]
            
        if("random" in inputType):
            print(list(masterDF[1048576].values))

        plot_pandas(
            df=masterDF,
            title="SampleSort CUDA, " + str(inputType.split("_")[1]) + " Input, main, Speed-up",
            xlabel="Num Processors",
            ylabel="Speed-Up",
            loglog=True
        )
